# %% [markdown]
# ## Filtros e Agrupamentos
# ### para saber qual mercado, campeonato, odd, etc deu mais lucro ou prejuízo e para coisas desse tipo

# %%
import pandas as pd

#Pandas Settings
pd.options.display.float_format = '{:,.2f}'.format

# %%
a = '3'
vis = 'atletico'

try:
    teste_df = pd.read_csv('teste_apagar.csv')
except:
    teste_df = pd.DataFrame()
    pass
df_filtro = pd.DataFrame(
    {'mandante':['atletico'],
     'visitante':['cruzeiro'],
     'placar':['0x2'],'teste_int':[a]}
) 

frames = [teste_df, df_filtro]

result_df = pd.concat(frames, sort=False)

try:
    result_df.drop(['Unnamed: 0'], inplace=True, axis=1)
except:
    pass

result_df = result_df.reset_index(drop=True)

result_df = result_df.apply(pd.to_numeric, errors='ignore')

display(result_df)

a = result_df.duplicated(subset=['teste_int', 'mandante'], keep='first').sum()

display(a)

#display(result_df)


result_df.to_csv('teste_apagar.csv') # se aqui eu colocasse index=False n precisava desse drop(['Unnamed: 0'])
# Out:
#    mandante visitante placar  teste_int
# 0  atletico  cruzeiro    0x2          3
# 0

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
# mandante     1 non-null object
# visitante    1 non-null object
# placar       1 non-null object
# teste_int    1 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 60.0+ bytes

# %%
# em cima era só teste. apagar o arquivo gerado se for prosseguir com os códigos aqui
# e usar no lugar no lugar do código acima, este

df_filtro = pd.DataFrame(
    {'mandante':['cruzeiro','atletico','atletico','cruzeiro'],
     'visitante':['atletico','cruzeiro','cruzeiro','atletico'],
     'placar':['0x2','2x2','3x3','3x0']}
)    

display(df_filtro)
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 1  atletico  cruzeiro    2x2
# 2  atletico  cruzeiro    3x3
# 3  cruzeiro  atletico    3x0

# %%
filtro_df = result_df[result_df['mandante'] == 'cruzeiro']
for key,row in filtro_df.iterrows():
    if row['placar'] == '3x3':
        print('oi')

# %%
# alterando nome de atributo de coluna. Para alterar o nome da coluna tem um exemplo 
# no notebook "Elo Score"

for key,row in df_filtro.iterrows():
    if row['mandante'] == 'cruzeiro':
        df_filtro.loc[key,'mandante'] = 'cru'
display(df_filtro)
# Out:
#    mandante visitante placar
# 0       cru  atletico    0x2
# 1  atletico  cruzeiro    2x2
# 2  atletico  cruzeiro    3x3
# 3       cru  atletico    3x0

# %%
# alterando nome de atributo de coluna. Para alterar o nome da coluna tem um exemplo 
# no notebook "Elo Score"

for key,row in df_filtro.iterrows():
    if row['visitante'] == 'cruzeiro':
        df_filtro.loc[key,'visitante']  = 'cru'
display(df_filtro)
# Out:
#    mandante visitante placar
# 0       cru  atletico    0x2
# 1  atletico       cru    2x2
# 2  atletico       cru    3x3
# 3       cru  atletico    3x0

# %%
# renomeando o nome cruzeiro como estava inicialmente

# alterando nome de atributo de coluna. Para alterar o nome da coluna tem um exemplo 
# no notebook "Elo Score"

for key,row in df_filtro.iterrows():
    if row['mandante'] == 'cru':
        df_filtro.loc[key,'mandante']  = 'cruzeiro'
    
    if row['visitante'] == 'cru':
        df_filtro.loc[key,'visitante'] = 'cruzeiro'
display(df_filtro)
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 1  atletico  cruzeiro    2x2
# 2  atletico  cruzeiro    3x3
# 3  cruzeiro  atletico    3x0

# %%
df_filtro
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 1  atletico  cruzeiro    2x2
# 2  atletico  cruzeiro    3x3
# 3  cruzeiro  atletico    3x0

# %%
cruzeiro_mandante = [True, False, False, True]

# %%
df_filtro[cruzeiro_mandante]
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 3  cruzeiro  atletico    3x0

# %%
# a maneira acima é idêntica à esta

df_filtro[[True, False, False, True]] # lembrar dos 2 colchetes pois é uma lista dentro de outra
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 3  cruzeiro  atletico    3x0

# %%
# como mostrado precisamos sabe se o que queremos é False ou True
# porém não dá para fazer assim como uma tabela grande
# usamos o conceito de True e False mas fazemos da maneira a seguir

filtro_cruzeiro_mandante = df_filtro['mandante'] == 'cruzeiro'
print(filtro_cruzeiro_mandante)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: mandante, dtype: bool

# %%
# de posse disso agora fazemos...

df_filtro[filtro_cruzeiro_mandante]
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 3  cruzeiro  atletico    3x0

# %%
# para não ter que criar uma variável podíamos na mesma lógica, apenas fazer:
# aqui estou filtrando valor de uma coluna (no caso cruzeiro da coluna mandante)

df_filtro[df_filtro['mandante'] == 'cruzeiro']
# Out:
#    mandante visitante placar
# 0  cruzeiro  atletico    0x2
# 3  cruzeiro  atletico    3x0

# %%
df_filtro['gols_mandante'] = df_filtro.apply(lambda row: int(row['placar'].split('x')[0]), axis=1)
df_filtro['gols_visitante'] = df_filtro.apply(lambda row: int(row['placar'].split('x')[1]), axis=1)
df_filtro['total_gols'] = df_filtro['gols_mandante'] + df_filtro['gols_visitante']
display(df_filtro)
# Out:
#    mandante visitante placar  gols_mandante  gols_visitante  total_gols
# 0  cruzeiro  atletico    0x2              0               2           2
# 1  atletico  cruzeiro    2x2              2               2           4
# 2  atletico  cruzeiro    3x3              3               3           6
# 3  cruzeiro  atletico    3x0              3               0           3

# %%
fover25 = df_filtro['total_gols'] > 2
print(fover25)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: total_gols, dtype: bool

# %%
display(df_filtro[fover25])
# Out:
#    mandante visitante placar  gols_mandante  gols_visitante  total_gols
# 1  atletico  cruzeiro    2x2              2               2           4
# 2  atletico  cruzeiro    3x3              3               3           6
# 3  cruzeiro  atletico    3x0              3               0           3

# %%
ambas = (df_filtro['gols_mandante'] > 0) & (df_filtro['gols_visitante'] > 0) # aqui tem que usar "&" e não "and"
print(ambas)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
df_filtro[ambas]
# Out:
#    mandante visitante placar  gols_mandante  gols_visitante  total_gols
# 1  atletico  cruzeiro    2x2              2               2           4
# 2  atletico  cruzeiro    3x3              3               3           6

# %%
# obs pra casos como o filtro acima, no lugar da sintaxe and, or, temos &, |...

fellabot = pd.read_excel('/home/andre/Downloads/novo_fellabot.xlsx')
fellabot.head()
# Out:
#                                              Partida        Mandante  \
# 0  https://www.betfellows.com/prognosticos/143252...      Fbc melgar
# 1  https://www.betfellows.com/prognosticos/143265...  Union comercio
# 2  https://www.betfellows.com/prognosticos/143253...   Utc cajamarca
# 3  https://www.betfellows.com/prognosticos/153181...           Ceara
# 4  https://www.betfellows.com/prognosticos/153181...           Ceara
#
#              Visitante Data e Hora da Partida   Data e Hora da Bet Desafio  \
# 0       Sport huancayo    05/05/2019 01:00:00  03/05/2019 04:25:56  Nenhum
# 1          Ayacucho fc    04/05/2019 18:15:00  03/05/2019 04:25:12  Nenhum
# 2  Deportivo municipal    04/05/2019 20:30:00  03/05/2019 04:24:34  Nenhum
# 3     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:05  Nenhum
# 4     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:02  Nenhum
#
#               Campeonato           Mercado Aposta Realizada  Odd  \
# 0  Peru Primera Division  Over/Under Goals        UNDER 2.5 1.80
# 1  Peru Primera Division  Over/Under Goals         OVER 2.5 1.85
# 2  Peru Primera Division  Over/Under Goals         OVER 2.5 2.05
# 3         Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 4         Brazil Serie A        Match Odds             AWAY 2.90
#
#    Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 0                                317.20                 3              Não
# 1                                320.20                 3              Não
# 2                                323.20                 3              Sim
# 3                                326.20                 3              Sim
# 4                                329.20                 3              Sim
#
#    Resultado
# 0      -3.00
# 1      -3.00
# 2       3.15
# 3       3.90
# 4       5.70

# %%
# se fizesse apenas como nas linhas abaixo, retornava apenas true e false para ser colocado como parâmetro
# do dataframe, então fiz tudo de uma vez
#ganhas = fellabot['Ganhou a aposta?'] == 'Sim'
#perdidas = fellabot['Ganhou a aposta?'] == 'Não'

ganhas = fellabot[fellabot['Ganhou a aposta?'] == 'Sim']
perdidas = fellabot[fellabot['Ganhou a aposta?'] == 'Não']

print('apostas ganhas\n')
display(ganhas)
print('apostas perdidas\n')
display(perdidas)
# Out:
# apostas ganhas
#                                                Partida  \
# 2    https://www.betfellows.com/prognosticos/143253...
# 3    https://www.betfellows.com/prognosticos/153181...
# 4    https://www.betfellows.com/prognosticos/153181...
# 5    https://www.betfellows.com/prognosticos/153107...
# 6    https://www.betfellows.com/prognosticos/153096...
# 7    https://www.betfellows.com/prognosticos/137091...
# 9    https://www.betfellows.com/prognosticos/137639...
# 10   https://www.betfellows.com/prognosticos/137639...
# 11   https://www.betfellows.com/prognosticos/137090...
# 14   https://www.betfellows.com/prognosticos/137091...
# 17   https://www.betfellows.com/prognosticos/935304...
# 20   https://www.betfellows.com/prognosticos/902496...
# 21   https://www.betfellows.com/prognosticos/902496...
# 24   https://www.betfellows.com/prognosticos/153113...
# 3                Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 4                Brazil Serie A        Match Odds             AWAY 2.90
# 5                Brazil Serie A        Match Odds             HOME 1.74
# 6                Brazil Serie A        Match Odds             DRAW 3.15
# 7               Mexico Clausura  Over/Under Goals         OVER 2.5 2.00
# 9               Mexico Clausura  Over/Under Goals         OVER 2.5 1.90
# 10              Mexico Clausura        Match Odds             HOME 1.66
# 11              Mexico Clausura  Over/Under Goals         OVER 2.5 2.05
# 14              Mexico Clausura  Over/Under Goals        UNDER 2.5 2.01
# 17                Italy Serie B        Match Odds             AWAY 5.05
# 20               France Ligue 1  Over/Under Goals         OVER 2.5 1.72
# 21               France Ligue 1        Match Odds             HOME 3.75
# 24               Brazil Serie A  Over/Under Goals         OVER 2.5 2.25
# 25               Brazil Serie A        Match Odds             AWAY 2.70
# 30           Colombia Primera A        Match Odds             HOME 4.60
# 35        Germany Bundesliga II  Over/Under Goals         OVER 2.5 1.44
# 37               France Ligue 2  Over/Under Goals        UNDER 2.5 1.70
# 41               France Ligue 2  Over/Under Goals         OVER 2.5 2.25
# 43               France Ligue 2  Over/Under Goals         OVER 2.5 1.90
# 45               France Ligue 2  Over/Under Goals        UNDER 2.5 1.50
# 46               France Ligue 2        Match Odds             AWAY 3.00
# 50         Germany Bundesliga I  Over/Under Goals        UNDER 2.5 2.30
# 51         Germany Bundesliga I        Match Odds             HOME 2.90
# 52                Italy Serie B        Match Odds             DRAW 3.20
# 56                Italy Serie B  Over/Under Goals         OVER 2.5 2.05
# 58       Portugal Primeira Liga  Over/Under Goals         OVER 2.5 2.30
# 59       Portugal Primeira Liga  Over/Under Goals         OVER 2.5 1.61
# 61         England Championship  Over/Under Goals         OVER 2.5 1.53
# 65         England Championship  Over/Under Goals         OVER 2.5 1.98
# ..                          ...               ...              ...  ...
# 262                     USA MLS  Over/Under Goals        UNDER 2.5 2.00
# 264            Uruguay Apertura        Match Odds             HOME 2.24
# 265             Mexico Clausura        Match Odds             HOME 2.85
# 266             Mexico Clausura  Over/Under Goals        UNDER 2.5 1.75
# 270             Mexico Clausura  Over/Under Goals        UNDER 2.5 2.00
# 274                     USA MLS  Over/Under Goals        UNDER 2.5 2.30
# 276                     USA MLS  Over/Under Goals         OVER 2.5 1.57
# 277                     USA MLS        Match Odds             HOME 2.85
# 283                     USA MLS        Match Odds             DRAW 4.20
# 284                     USA MLS        Match Odds             DRAW 4.00
# 285        Argentina Nacional B        Match Odds             HOME 2.38
# 286        Argentina Nacional B        Match Odds             HOME 2.50
# 289          Holland Eredivisie        Match Odds             AWAY 1.95
# 290          Holland Eredivisie        Match Odds             DRAW 3.60
# 296               Italy Serie A        Match Odds             HOME 1.61
# 298               Italy Serie A  Over/Under Goals         OVER 2.5 2.30
# 301               Italy Serie A        Match Odds             HOME 2.40
# 304          Spain Primera Liga  Over/Under Goals         OVER 2.5 2.10
# 309          Colombia Primera A  Over/Under Goals        UNDER 2.5 1.67
# 310          Colombia Primera A  Over/Under Goals        UNDER 2.5 1.57
# 311  Venezuela Primera Division        Match Odds             DRAW 3.50
# 312  Venezuela Primera Division        Match Odds             AWAY 2.90
# 316          Colombia Primera A  Over/Under Goals         OVER 2.5 2.10
# 322          Colombia Primera A        Match Odds             AWAY 3.00
# 323            Uruguay Apertura  Over/Under Goals        UNDER 2.5 2.05
# 324            Uruguay Apertura        Match Odds             DRAW 3.30
# 326            Uruguay Apertura        Match Odds             DRAW 4.33
# 329            Uruguay Apertura  Over/Under Goals        UNDER 2.5 2.30
# 331       Peru Primera Division  Over/Under Goals        UNDER 2.5 2.10
# 344              Brazil Serie A        Match Odds             HOME 1.61
#
#      Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 2                                  323.20                 3              Sim
# 3                                  326.20                 3              Sim
# 4                                  329.20                 3              Sim
# 5                                  332.20                 3              Sim
# 6                                  335.20                 3              Sim
# 7                                  338.20                 3              Sim
# 9                                  344.20                 3              Sim
# 10                                 347.20                 3              Sim
# 11                                 350.20                 3              Sim
# 14                                 359.20                 3              Sim
# 17                                 307.99                 3              Sim
# 20                                 316.99                 3              Sim
# 21                                 319.99                 3              Sim
# 24                                 328.99                 3              Sim
# 25                                 331.99                 3              Sim
# 30                                 346.99                 3              Sim
# 35                                 176.63                 1              Sim
# 37                                 178.63                 1              Sim
# 41                                 182.63                 1              Sim
# 43                                 184.63                 1              Sim
# 45                                 186.63                 1              Sim
# 46                                 187.63                 1              Sim
# 50                                 191.63                 1              Sim
# 51                                 192.63                 1              Sim
# 52                                 193.63                 1              Sim
# 56                                 198.63                 2              Sim
# 58                                 202.63                 2              Sim
# 59                                 204.63                 2              Sim
# 61                                 208.63                 2              Sim
# 65                                 216.63                 2              Sim
# ..                                    ...               ...              ...
# 262                                448.91                 4              Sim
# 264                                360.93                 3              Sim
# 265                                363.93                 3              Sim
# 266                                366.93                 3              Sim
# 270                                378.93                 3              Sim
# 274                                390.93                 3              Sim
# 276                                396.93                 3              Sim
# 277                                399.93                 3              Sim
# 283                                419.93                 4              Sim
# 284                                423.93                 4              Sim
# 285                                427.93                 4              Sim
# 286                                431.93                 4              Sim
# 289                                390.61                 3              Sim
# 290                                393.61                 3              Sim
# 296                                415.61                 4              Sim
# 298                                423.61                 4              Sim
# 301                                435.61                 4              Sim
# 304                                447.61                 4              Sim
# 309                                454.65                 4              Sim
# 310                                458.65                 4              Sim
# 311                                367.82                 3              Sim
# 312                                370.82                 3              Sim
# 316                                382.82                 3              Sim
# 322                                401.82                 4              Sim
# 323                                405.82                 4              Sim
# 324                                409.82                 4              Sim
# 326                                417.82                 4              Sim
# 329                                429.82                 4              Sim
# 331                                437.82                 4              Sim
# 344                                343.63                 3              Sim
#
#      Resultado
# 2         3.15
# 3         3.90
# 4         5.70
# 5         2.22
# 6         6.45
# 7         3.00
# 9         2.70
# 10        1.98
# 11        3.15
# 14        3.03
# 17       12.15
# 20        2.16
# 21        8.25
# 24        3.75
# 25        5.10
# 30       10.80
# 35        0.44
# 37        0.70
# 41        1.25
# 43        0.90
# 45        0.50
# 46        2.00
# 50        1.30
# 51        1.90
# 53                Italy Serie B        Match Odds             AWAY 3.15
# 54                Italy Serie B        Match Odds             AWAY 2.90
# ..                          ...               ...              ...  ...
# 306          Spain Primera Liga        Match Odds             DRAW 4.33
# 307          Spain Primera Liga        Match Odds             DRAW 4.00
# 308          Colombia Primera A        Match Odds             DRAW 3.00
# 313          Colombia Primera A  Over/Under Goals         OVER 2.5 2.60
# 314          Colombia Primera A        Match Odds             HOME 2.09
# 315          Colombia Primera A        Match Odds             AWAY 7.00
# 317          Colombia Primera A        Match Odds             AWAY 7.40
# 318          Colombia Primera A  Over/Under Goals        UNDER 2.5 1.66
# 319          Colombia Primera A        Match Odds             DRAW 3.50
# 320          Colombia Primera A  Over/Under Goals         OVER 2.5 2.20
# 321          Colombia Primera A        Match Odds             AWAY 6.45
# 325            Uruguay Apertura  Over/Under Goals        UNDER 2.5 2.20
# 327            Uruguay Apertura  Over/Under Goals        UNDER 2.5 2.20
# 328            Uruguay Apertura        Match Odds             DRAW 3.30
# 330       Peru Primera Division  Over/Under Goals        UNDER 2.5 1.85
# 332       Peru Primera Division        Match Odds             HOME 4.75
# 333                     USA MLS        Match Odds             AWAY 3.25
# 334        Argentina Nacional B  Over/Under Goals        UNDER 2.5 1.47
# 335        Argentina Nacional B        Match Odds             DRAW 3.10
# 336                     USA MLS        Match Odds             DRAW 4.75
# 337                     USA MLS        Match Odds             DRAW 4.75
# 338                     USA MLS        Match Odds             AWAY 5.95
# 339               Spain Segunda        Match Odds             DRAW 2.95
# 340  Venezuela Primera Division        Match Odds             DRAW 3.80
# 341  Venezuela Primera Division        Match Odds             HOME 3.35
# 342          Holland Eredivisie        Match Odds             DRAW 3.80
# 343          Holland Eredivisie  Over/Under Goals        UNDER 2.5 2.30
# 345                     USA MLS  Over/Under Goals         OVER 2.5 1.72
# 346                     USA MLS  Over/Under Goals         OVER 2.5 1.70
# 347                     USA MLS        Match Odds             HOME 1.50
#
#      Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 0                                  317.20                 3              Não
# 1                                  320.20                 3              Não
# 8                                  341.20                 3              Não
# 12                                 353.20                 3              Não
# 13                                 356.20                 3              Não
# 15                                 362.20                 3              Não
# 16                                 304.99                 3              Não
# 18                                 310.99                 3              Não
# 19                                 313.99                 3              Não
# 22                                 322.99                 3              Não
# 23                                 325.99                 3              Não
# 26                                 334.99                 3              Não
# 27                                 337.99                 3              Não
# 28                                 340.99                 3              Não
# 29                                 343.99                 3              Não
# 31                                 172.63                 1              Não
# 32                                 173.63                 1              Não
# 33                                 174.63                 1              Não
# 34                                 175.63                 1              Não
# 36                                 177.63                 1              Não
# 38                                 179.63                 1              Não
# 39                                 180.63                 1              Não
# 40                                 181.63                 1              Não
# 42                                 183.63                 1              Não
# 44                                 185.63                 1              Não
# 47                                 188.63                 1              Não
# 48                                 189.63                 1              Não
# 49                                 190.63                 1              Não
# 53                                 194.63                 1              Não
# 54                                 195.63                 1              Não
# ..                                    ...               ...              ...
# 306                                455.61                 4              Não
# 307                                459.61                 4              Não
# 308                                463.61                 4              Não
# 313                                373.82                 3              Não
# 314                                376.82                 3              Não
# 315                                379.82                 3              Não
# 317                                385.82                 3              Não
# 318                                388.82                 3              Não
# 319                                391.82                 3              Não
# 320                                394.82                 3              Não
# 321                                397.82                 3              Não
# 325                                413.82                 4              Não
# 327                                421.82                 4              Não
# 328                                425.82                 4              Não
# 330                                433.82                 4              Não
# 332                                441.82                 4              Não
# 333                                445.82                 4              Não
# 334                                449.82                 4              Não
# 335                                453.82                 4              Não
# 336                                457.82                 4              Não
# 337                                461.82                 4              Não
# 338                                465.82                 4              Não
# 339                                469.82                 4              Não
# 340                                473.82                 4              Não
# 341                                477.82                 4              Não
# 342                                311.63                 3              Não
# 343                                308.63                 3              Não
# 345                                334.63                 3              Não
# 346                                325.63                 3              Não
# 347                                322.63                 3              Não
#
#      Resultado
# 0        -3.00
# 1        -3.00
# 8        -3.00
# 12       -3.00
# 13       -3.00
# 15       -3.00
# 16       -3.00
# 18       -3.00
# 19       -3.00
# 22       -3.00
# 23       -3.00
# 26       -3.00
# 27       -3.00
# 28       -3.00
# 29       -3.00
# 31       -1.00
# 32       -1.00
# 33       -1.00
# 34       -1.00
# 36       -1.00
# 38       -1.00
# 39       -1.00
# 40       -1.00
# 42       -1.00
# 44       -1.00
# 47       -1.00
# 48       -1.00
# 49       -1.00
# 53       -1.00
# 54       -1.00
# ..         ...
# 306      -4.00
# 307      -4.00
# 308      -4.00
# 313      -3.00
# 314      -3.00
# 315      -3.00
# 317      -3.00
# 318      -3.00
# 319      -3.00
# 320      -3.00
# 321      -3.00
# 325      -4.00
# 327      -4.00
# 328      -4.00
# 330      -4.00
# 332      -4.00
# 333      -4.00
# 334      -4.00
# 335      -4.00
# 336      -4.00
# 337      -4.00
# 338      -4.00
# 339      -4.00
# 340      -4.00
# 341      -4.00
# 342      -3.00
# 343      -3.00
# 345      -3.00
# 346      -3.00
# 347      -3.00
#
# [221 rows x 14 columns]

# %%
fellabot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348 entries, 0 to 347
# Data columns (total 14 columns):
# Partida                                 348 non-null object
# Mandante                                348 non-null object
# Visitante                               348 non-null object
# Data e Hora da Partida                  348 non-null object
# Data e Hora da Bet                      348 non-null object
# Desafio                                 348 non-null object
# Campeonato                              348 non-null object
# Mercado                                 348 non-null object
# Aposta Realizada                        348 non-null object
# Odd                                     348 non-null float64
# Valor da Banca No Momento da Entrada    348 non-null float64
# Valor da Entrada                        348 non-null int64
# Ganhou a aposta?                        348 non-null object
# Resultado                               348 non-null float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 27.2+ KB

# %% [markdown]
# ## Agrupamento de dados com pandas
#
# ### 1a maneira de fazer - não a melhor opção
# ##### depois vamos ver a melhor opção

# %%
fellabot['Mercado'] # assim ele repete mercados
# Out:
# 0      Over/Under Goals
# 1      Over/Under Goals
# 2      Over/Under Goals
# 3      Over/Under Goals
# 4            Match Odds
# 5            Match Odds
# 6            Match Odds
# 7      Over/Under Goals
# 8            Match Odds
# 9      Over/Under Goals
# 10           Match Odds
# 11     Over/Under Goals
# 12     Over/Under Goals
# 13           Match Odds
# 14     Over/Under Goals
# 15           Match Odds
# 16           Match Odds
# 17           Match Odds
# 18           Match Odds
# 19           Match Odds
# 20     Over/Under Goals
# 21           Match Odds
# 22     Over/Under Goals
# 23           Match Odds
# 24     Over/Under Goals
# 25           Match Odds
# 26     Over/Under Goals
# 27           Match Odds
# 28     Over/Under Goals
# 29           Match Odds
#              ...
# 318    Over/Under Goals
# 319          Match Odds
# 320    Over/Under Goals
# 321          Match Odds
# 322          Match Odds
# 323    Over/Under Goals
# 324          Match Odds
# 325    Over/Under Goals
# 326          Match Odds
# 327    Over/Under Goals
# 328          Match Odds
# 329    Over/Under Goals
# 330    Over/Under Goals
# 331    Over/Under Goals
# 332          Match Odds
# 333          Match Odds
# 334    Over/Under Goals
# 335          Match Odds
# 336          Match Odds
# 337          Match Odds
# 338          Match Odds
# 339          Match Odds
# 340          Match Odds
# 341          Match Odds
# 342          Match Odds
# 343    Over/Under Goals
# 344          Match Odds
# 345    Over/Under Goals
# 346    Over/Under Goals
# 347          Match Odds
# Name: Mercado, Length: 348, dtype: object

# %%
fellabot['Mercado'].unique() # usando o unique() não repete mercados
# Out:
# array(['Over/Under Goals', 'Match Odds'], dtype=object)

# %%
mercados_unicos = fellabot['Mercado'].unique()

for mercado in mercados_unicos:
    df_mercado = fellabot[fellabot['Mercado'] == mercado] # df_mercado está recebendo um dataframe logo se torna DF tbm
    print(f'Análise do mercado {mercado}')
    display(df_mercado)
# Out:
# Análise do mercado Over/Under Goals
#                                                Partida  \
# 0    https://www.betfellows.com/prognosticos/143252...
# 1    https://www.betfellows.com/prognosticos/143265...
# 2    https://www.betfellows.com/prognosticos/143253...
# 3    https://www.betfellows.com/prognosticos/153181...
# 7    https://www.betfellows.com/prognosticos/137091...
# 9    https://www.betfellows.com/prognosticos/137639...
# 11   https://www.betfellows.com/prognosticos/137090...
# 12   https://www.betfellows.com/prognosticos/137090...
# 14   https://www.betfellows.com/prognosticos/137091...
# 20   https://www.betfellows.com/prognosticos/902496...
# 22   https://www.betfellows.com/prognosticos/140600...
# 24   https://www.betfellows.com/prognosticos/153113...
# 26   https://www.betfellows.com/prognosticos/153178...
# 28   https://www.betfellows.com/prognosticos/153113...
# 31   https://www.betfellows.com/prognosticos/878607...
# 34   https://www.betfellows.com/prognosticos/873169...
# 35   https://www.betfellows.com/prognosticos/873168...
# 37   https://www.betfellows.com/prognosticos/897303...
# 39   https://www.betfellows.com/prognosticos/897301...
# 40   https://www.betfellows.com/prognosticos/897304...
# 41   https://www.betfellows.com/prognosticos/891894...
# 43   https://www.betfellows.com/prognosticos/891893...
# 45   https://www.betfellows.com/prognosticos/891891...
# 50   https://www.betfellows.com/prognosticos/893367...
# 56   https://www.betfellows.com/prognosticos/935300...
# 58   https://www.betfellows.com/prognosticos/157345...
# 59   https://www.betfellows.com/prognosticos/157346...
# 61   https://www.betfellows.com/prognosticos/157357...
# 63   https://www.betfellows.com/prognosticos/157357...
# 65   https://www.betfellows.com/prognosticos/992958...
# ..                                                 ...
# 313  23/03/2019 04:40:25  Nenhum      Colombia Primera A  Over/Under Goals
# 316  23/03/2019 04:40:01  Nenhum      Colombia Primera A  Over/Under Goals
# 318  23/03/2019 04:39:52  Nenhum      Colombia Primera A  Over/Under Goals
# 320  23/03/2019 04:39:43  Nenhum      Colombia Primera A  Over/Under Goals
# 323  23/03/2019 04:39:19  Nenhum        Uruguay Apertura  Over/Under Goals
# 325  23/03/2019 04:39:09  Nenhum        Uruguay Apertura  Over/Under Goals
# 327  23/03/2019 04:38:57  Nenhum        Uruguay Apertura  Over/Under Goals
# 329  23/03/2019 04:38:47  Nenhum        Uruguay Apertura  Over/Under Goals
# 330  23/03/2019 04:38:38  Nenhum   Peru Primera Division  Over/Under Goals
# 331  23/03/2019 04:38:31  Nenhum   Peru Primera Division  Over/Under Goals
# 334  22/03/2019 04:35:49  Nenhum    Argentina Nacional B  Over/Under Goals
# 343  23/05/2019 15:10:17  Nenhum      Holland Eredivisie  Over/Under Goals
# 345  23/05/2019 15:10:17  Nenhum                 USA MLS  Over/Under Goals
# 346  23/05/2019 15:10:17  Nenhum                 USA MLS  Over/Under Goals
#
#     Aposta Realizada  Odd  Valor da Banca No Momento da Entrada  \
# 0          UNDER 2.5 1.80                                317.20
# 1           OVER 2.5 1.85                                320.20
# 2           OVER 2.5 2.05                                323.20
# 3           OVER 2.5 2.30                                326.20
# 7           OVER 2.5 2.00                                338.20
# 9           OVER 2.5 1.90                                344.20
# 11          OVER 2.5 2.05                                350.20
# 12          OVER 2.5 2.00                                353.20
# 14         UNDER 2.5 2.01                                359.20
# 20          OVER 2.5 1.72                                316.99
# 22          OVER 2.5 1.72                                322.99
# 24          OVER 2.5 2.25                                328.99
# 26          OVER 2.5 2.10                                334.99
# 28          OVER 2.5 2.40                                340.99
# 31          OVER 2.5 2.05                                172.63
# 34          OVER 2.5 1.82                                175.63
# 35          OVER 2.5 1.44                                176.63
# 37         UNDER 2.5 1.70                                178.63
# 39          OVER 2.5 2.35                                180.63
# 40          OVER 2.5 2.15                                181.63
# 41          OVER 2.5 2.25                                182.63
# 43          OVER 2.5 1.90                                184.63
# 45         UNDER 2.5 1.50                                186.63
# 50         UNDER 2.5 2.30                                191.63
# 56          OVER 2.5 2.05                                198.63
# 58          OVER 2.5 2.30                                202.63
# 59          OVER 2.5 1.61                                204.63
# 61          OVER 2.5 1.53                                208.63
# 63          OVER 2.5 1.57                                212.63
# 65          OVER 2.5 1.98                                216.63
# ..               ...  ...                                   ...
# 262        UNDER 2.5 2.00                                448.91
# 266        UNDER 2.5 1.75                                366.93
# 268        UNDER 2.5 2.40                                372.93
# 270        UNDER 2.5 2.00                                378.93
# 272        UNDER 2.5 1.75                                384.93
# 274        UNDER 2.5 2.30                                390.93
# 276         OVER 2.5 1.57                                396.93
# 291        UNDER 2.5 1.70                                396.61
# 297        UNDER 2.5 2.10                                419.61
# 298         OVER 2.5 2.30                                423.61
# 299         OVER 2.5 1.96                                427.61
# 300        UNDER 2.5 1.66                                431.61
# 303         OVER 2.5 2.20                                443.61
# 304         OVER 2.5 2.10                                447.61
# 309        UNDER 2.5 1.67                                454.65
# 310        UNDER 2.5 1.57                                458.65
# 313         OVER 2.5 2.60                                373.82
# 316         OVER 2.5 2.10                                382.82
# 318        UNDER 2.5 1.66                                388.82
# 320         OVER 2.5 2.20                                394.82
# 323        UNDER 2.5 2.05                                405.82
# 325        UNDER 2.5 2.20                                413.82
# 327        UNDER 2.5 2.20                                421.82
# 329        UNDER 2.5 2.30                                429.82
# 330        UNDER 2.5 1.85                                433.82
# 331        UNDER 2.5 2.10                                437.82
# 334        UNDER 2.5 1.47                                449.82
# 343        UNDER 2.5 2.30                                308.63
# 345         OVER 2.5 1.72                                334.63
# 346         OVER 2.5 1.70                                325.63
#
#      Valor da Entrada Ganhou a aposta?  Resultado
# 0                   3              Não      -3.00
# 1                   3              Não      -3.00
# 2                   3              Sim       3.15
# 3                   3              Sim       3.90
# 7                   3              Sim       3.00
# 9                   3              Sim       2.70
# 11                  3              Sim       3.15
# 12                  3              Não      -3.00
# 14                  3              Sim       3.03
# 20                  3              Sim       2.16
# 22                  3              Não      -3.00
# 24                  3              Sim       3.75
# 26                  3              Não      -3.00
# 28                  3              Não      -3.00
# 31                  1              Não      -1.00
# 34                  1              Não      -1.00
# 35                  1              Sim       0.44
# 37                  1              Sim       0.70
# 39                  1              Não      -1.00
# 40                  1              Não      -1.00
# 41                  1              Sim       1.25
# 43                  1              Sim       0.90
# 45                  1              Sim       0.50
# 50                  1              Sim       1.30
# 56                  2              Sim       2.10
# 58                  2              Sim       2.60
# 59                  2              Sim       1.22
# 61                  2              Sim       1.06
# 63                  2              Não      -2.00
# 65                  2              Sim       1.95
# ..                ...              ...        ...
# 262                 4              Sim       4.00
# 266                 3              Sim       2.25
# 268                 3              Não      -3.00
# 270                 3              Sim       3.00
# 272                 3              Não      -3.00
# 274                 3              Sim       3.90
# 276                 3              Sim       1.71
# 291                 3              Não      -3.00
# 297                 4              Não      -4.00
# 298                 4              Sim       5.20
# 299                 4              Não      -4.00
# 300                 4              Não      -4.00
# 303                 4              Não      -4.00
# 304                 4              Sim       4.40
# 309                 4              Sim       2.68
# 310                 4              Sim       2.28
# 313                 3              Não      -3.00
# 316                 3              Sim       3.30
# 318                 3              Não      -3.00
# 320                 3              Não      -3.00
# 323                 4              Sim       4.20
# 325                 4              Não      -4.00
# 327                 4              Não      -4.00
# 329                 4              Sim       5.20
# 330                 4              Não      -4.00
# 331                 4              Sim       4.40
# 334                 4              Não      -4.00
# 343                 3              Não      -3.00
# 345                 3              Não      -3.00
# 346                 3              Não      -3.00
#
# [132 rows x 14 columns]
# Análise do mercado Match Odds
#                                                Partida  \
# 4    https://www.betfellows.com/prognosticos/153181...
# 5    https://www.betfellows.com/prognosticos/153107...
# 6    https://www.betfellows.com/prognosticos/153096...
# 8    https://www.betfellows.com/prognosticos/137091...
# 10   https://www.betfellows.com/prognosticos/137639...
# 13   https://www.betfellows.com/prognosticos/137090...
# 15   https://www.betfellows.com/prognosticos/137091...
# 16   https://www.betfellows.com/prognosticos/935301...
# 333                     USA MLS  Match Odds             AWAY 3.25
# 335        Argentina Nacional B  Match Odds             DRAW 3.10
# 336                     USA MLS  Match Odds             DRAW 4.75
# 337                     USA MLS  Match Odds             DRAW 4.75
# 338                     USA MLS  Match Odds             AWAY 5.95
# 339               Spain Segunda  Match Odds             DRAW 2.95
# 340  Venezuela Primera Division  Match Odds             DRAW 3.80
# 341  Venezuela Primera Division  Match Odds             HOME 3.35
# 342          Holland Eredivisie  Match Odds             DRAW 3.80
# 344              Brazil Serie A  Match Odds             HOME 1.61
# 347                     USA MLS  Match Odds             HOME 1.50
#
#      Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 4                                  329.20                 3              Sim
# 5                                  332.20                 3              Sim
# 6                                  335.20                 3              Sim
# 8                                  341.20                 3              Não
# 10                                 347.20                 3              Sim
# 13                                 356.20                 3              Não
# 15                                 362.20                 3              Não
# 16                                 304.99                 3              Não
# 17                                 307.99                 3              Sim
# 18                                 310.99                 3              Não
# 19                                 313.99                 3              Não
# 21                                 319.99                 3              Sim
# 23                                 325.99                 3              Não
# 25                                 331.99                 3              Sim
# 27                                 337.99                 3              Não
# 29                                 343.99                 3              Não
# 30                                 346.99                 3              Sim
# 32                                 173.63                 1              Não
# 33                                 174.63                 1              Não
# 36                                 177.63                 1              Não
# 38                                 179.63                 1              Não
# 42                                 183.63                 1              Não
# 44                                 185.63                 1              Não
# 46                                 187.63                 1              Sim
# 47                                 188.63                 1              Não
# 48                                 189.63                 1              Não
# 49                                 190.63                 1              Não
# 51                                 192.63                 1              Sim
# 52                                 193.63                 1              Sim
# 53                                 194.63                 1              Não
# ..                                    ...               ...              ...
# 296                                415.61                 4              Sim
# 301                                435.61                 4              Sim
# 302                                439.61                 4              Não
# 305                                451.61                 4              Não
# 306                                455.61                 4              Não
# 307                                459.61                 4              Não
# 308                                463.61                 4              Não
# 311                                367.82                 3              Sim
# 312                                370.82                 3              Sim
# 314                                376.82                 3              Não
# 315                                379.82                 3              Não
# 317                                385.82                 3              Não
# 319                                391.82                 3              Não
# 321                                397.82                 3              Não
# 322                                401.82                 4              Sim
# 324                                409.82                 4              Sim
# 326                                417.82                 4              Sim
# 328                                425.82                 4              Não
# 332                                441.82                 4              Não
# 333                                445.82                 4              Não
# 335                                453.82                 4              Não
# 336                                457.82                 4              Não
# 337                                461.82                 4              Não
# 338                                465.82                 4              Não
# 339                                469.82                 4              Não
# 340                                473.82                 4              Não
# 341                                477.82                 4              Não
# 342                                311.63                 3              Não
# 344                                343.63                 3              Sim
# 347                                322.63                 3              Não
#
#      Resultado
# 4         5.70
# 5         2.22
# 6         6.45
# 8        -3.00
# 10        1.98
# 13       -3.00
# 15       -3.00
# 16       -3.00
# 17       12.15
# 18       -3.00
# 19       -3.00
# 21        8.25
# 23       -3.00
# 25        5.10
# 27       -3.00
# 29       -3.00
# 30       10.80
# 32       -1.00
# 33       -1.00
# 36       -1.00
# 38       -1.00
# 42       -1.00
# 44       -1.00
# 46        2.00
# 47       -1.00
# 48       -1.00
# 49       -1.00
# 51        1.90
# 52        2.20
# 53       -1.00
# ..         ...
# 296       2.46
# 301       5.60
# 302      -4.00
# 305      -4.00
# 306      -4.00
# 307      -4.00
# 308      -4.00
# 311       7.50
# 312       5.70
# 314      -3.00
# 315      -3.00
# 317      -3.00
# 319      -3.00
# 321      -3.00
# 322       8.00
# 324       9.20
# 326      13.33
# 328      -4.00
# 332      -4.00
# 333      -4.00
# 335      -4.00
# 336      -4.00
# 337      -4.00
# 338      -4.00
# 339      -4.00
# 340      -4.00
# 341      -4.00
# 342      -3.00
# 344       1.84
# 347      -3.00
#
# [216 rows x 14 columns]

# %%
# mesmo exemplo anterior mas agora saber a média
mercados_unicos = fellabot['Mercado'].unique()

for mercado in mercados_unicos:
    df_mercado = fellabot[fellabot['Mercado'] == mercado] # df_mercado está recebendo um dataframe logo se torna DF tbm
    print(f'Análise do mercado {mercado}')
    display(df_mercado.mean()) # apresenta a média de todas as colunas do dataframe df_mercado 
                               # que sejam valores numéricos
# Out:
# Análise do mercado Over/Under Goals
# Odd                                      1.96
# Valor da Banca No Momento da Entrada   332.74
# Valor da Entrada                         2.85
# Resultado                               -0.17
# dtype: float64
# Análise do mercado Match Odds
# Odd                                      3.80
# Valor da Banca No Momento da Entrada   336.47
# Valor da Entrada                         2.84
# Resultado                               -0.38
# dtype: float64

# %%
mercados_unicos = fellabot['Mercado'].unique()

for mercado in mercados_unicos:
    df_mercado = fellabot[fellabot['Mercado'] == mercado] # df_mercado está recebendo um dataframe logo se torna DF tbm
    apostas_unicas = df_mercado['Aposta Realizada'].unique()
    
    for aposta in apostas_unicas:
        df_aposta = df_mercado[df_mercado['Aposta Realizada'] == aposta]
        print(f'Análise do mercado {mercado} na aposta {aposta}')
        display(df_aposta.mean()) # média de todos os valores numéricos do df "df_aposta"
# Out:
# Análise do mercado Over/Under Goals na aposta UNDER 2.5
# Odd                                      1.88
# Valor da Banca No Momento da Entrada   364.11
# Valor da Entrada                         3.14
# Resultado                                0.14
# dtype: float64
# Análise do mercado Over/Under Goals na aposta OVER 2.5
# Odd                                      2.00
# Valor da Banca No Momento da Entrada   317.05
# Valor da Entrada                         2.70
# Resultado                               -0.33
# dtype: float64
# Análise do mercado Match Odds na aposta AWAY
# Odd                                      4.51
# Valor da Banca No Momento da Entrada   311.88
# Valor da Entrada                         2.61
# Resultado                               -0.22
# dtype: float64
# Análise do mercado Match Odds na aposta HOME
# Odd                                      2.66
# Valor da Banca No Momento da Entrada   340.56
# Valor da Entrada                         2.86
# Resultado                               -0.41
# dtype: float64
# Análise do mercado Match Odds na aposta DRAW
# Odd                                      4.53
# Valor da Banca No Momento da Entrada   353.33
# Valor da Entrada                         3.03
# Resultado                               -0.50
# dtype: float64

# %% [markdown]
# ## Agora fazendo o agrupamento de uma forma mais efetiva
# ## 2a maneira usando o groupby

# %%
fellabot.groupby(['Mercado']).mean()
# Out:
#                   Odd  Valor da Banca No Momento da Entrada  Valor da Entrada  \
# Mercado
# Match Odds       3.80                                336.47              2.84
# Over/Under Goals 1.96                                332.74              2.85
#
#                   Resultado
# Mercado
# Match Odds            -0.38
# Over/Under Goals      -0.17

# %%
fellabot.groupby(['Aposta Realizada']).mean()
# Out:
#                   Odd  Valor da Banca No Momento da Entrada  Valor da Entrada  \
# Aposta Realizada
# AWAY             4.51                                311.88              2.61
# DRAW             4.53                                353.33              3.03
# HOME             2.66                                340.56              2.86
# OVER 2.5         2.00                                317.05              2.70
# UNDER 2.5        1.88                                364.11              3.14
#
#                   Resultado
# Aposta Realizada
# AWAY                  -0.22
# DRAW                  -0.50
# HOME                  -0.41
# OVER 2.5              -0.33
# UNDER 2.5              0.14

# %%
# e se eu quisesse como no exemplo da 1a maneira agrupar por aposta realizada mas que esta estivesse
# agrupada em mercado. Bem mais simples com o groupby. fazemos isso em apenas uma linha...

fellabot.groupby(['Mercado', 'Aposta Realizada']).mean()
# Out:
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Mercado          Aposta Realizada
# Match Odds       AWAY             4.51                                311.88
#                  DRAW             4.53                                353.33
#                  HOME             2.66                                340.56
# Over/Under Goals OVER 2.5         2.00                                317.05
#                  UNDER 2.5        1.88                                364.11
#
#                                    Valor da Entrada  Resultado
# Mercado          Aposta Realizada
# Match Odds       AWAY                          2.61      -0.22
#                  DRAW                          3.03      -0.50
#                  HOME                          2.86      -0.41
# Over/Under Goals OVER 2.5                      2.70      -0.33
#                  UNDER 2.5                     3.14       0.14

# %%
fellabot.head()
# Out:
#                                              Partida        Mandante  \
# 0  https://www.betfellows.com/prognosticos/143252...      Fbc melgar
# 1  https://www.betfellows.com/prognosticos/143265...  Union comercio
# 2  https://www.betfellows.com/prognosticos/143253...   Utc cajamarca
# 3  https://www.betfellows.com/prognosticos/153181...           Ceara
# 4  https://www.betfellows.com/prognosticos/153181...           Ceara
#
#              Visitante Data e Hora da Partida   Data e Hora da Bet Desafio  \
# 0       Sport huancayo    05/05/2019 01:00:00  03/05/2019 04:25:56  Nenhum
# 1          Ayacucho fc    04/05/2019 18:15:00  03/05/2019 04:25:12  Nenhum
# 2  Deportivo municipal    04/05/2019 20:30:00  03/05/2019 04:24:34  Nenhum
# 3     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:05  Nenhum
# 4     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:02  Nenhum
#
#               Campeonato           Mercado Aposta Realizada  Odd  \
# 0  Peru Primera Division  Over/Under Goals        UNDER 2.5 1.80
# 1  Peru Primera Division  Over/Under Goals         OVER 2.5 1.85
# 2  Peru Primera Division  Over/Under Goals         OVER 2.5 2.05
# 3         Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 4         Brazil Serie A        Match Odds             AWAY 2.90
#
#    Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 0                                317.20                 3              Não
# 1                                320.20                 3              Não
# 2                                323.20                 3              Sim
# 3                                326.20                 3              Sim
# 4                                329.20                 3              Sim
#
#    Resultado     odds_bin
# 0      -3.00  (1.75, 2.0]
# 1      -3.00  (1.75, 2.0]
# 2       3.15  (2.0, 2.25]
# 3       3.90  (2.25, 2.5]
# 4       5.70   (2.5, 3.0]

# %%
fellabot[(fellabot['Mercado'] == 'Over/Under Goals') & (fellabot['Aposta Realizada'] == 'OVER 2.5')].head()
# Out:
#                                              Partida        Mandante  \
# 1  https://www.betfellows.com/prognosticos/143265...  Union comercio
# 2  https://www.betfellows.com/prognosticos/143253...   Utc cajamarca
# 3  https://www.betfellows.com/prognosticos/153181...           Ceara
# 7  https://www.betfellows.com/prognosticos/137091...         Tijuana
# 9  https://www.betfellows.com/prognosticos/137639...          Tigres
#
#              Visitante Data e Hora da Partida   Data e Hora da Bet Desafio  \
# 1          Ayacucho fc    04/05/2019 18:15:00  03/05/2019 04:25:12  Nenhum
# 2  Deportivo municipal    04/05/2019 20:30:00  03/05/2019 04:24:34  Nenhum
# 3     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:05  Nenhum
# 7               Puebla    05/05/2019 02:06:00  03/05/2019 04:16:11  Nenhum
# 9   Chivas guadalajara    05/05/2019 00:00:00  03/05/2019 04:14:51  Nenhum
#
#               Campeonato           Mercado Aposta Realizada  Odd  \
# 1  Peru Primera Division  Over/Under Goals         OVER 2.5 1.85
# 2  Peru Primera Division  Over/Under Goals         OVER 2.5 2.05
# 3         Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 7        Mexico Clausura  Over/Under Goals         OVER 2.5 2.00
# 9        Mexico Clausura  Over/Under Goals         OVER 2.5 1.90
#
#    Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 1                                320.20                 3              Não
# 2                                323.20                 3              Sim
# 3                                326.20                 3              Sim
# 7                                338.20                 3              Sim
# 9                                344.20                 3              Sim
#
#    Resultado     odds_bin
# 1      -3.00  (1.75, 2.0]
# 2       3.15  (2.0, 2.25]
# 3       3.90  (2.25, 2.5]
# 7       3.00  (1.75, 2.0]
# 9       2.70  (1.75, 2.0]

# %%
filtroaaa = fellabot.loc[0:,'Campeonato':'Aposta Realizada':2] # esse 2 é para mostrar apenas as 2 colunas
                                                               # caso contrário mostra todas desde "Campeonato" até "Aposta Realizada"
filtroaaa
# Out:
#                      Campeonato Aposta Realizada
# 0         Peru Primera Division        UNDER 2.5
# 1         Peru Primera Division         OVER 2.5
# 2         Peru Primera Division         OVER 2.5
# 3                Brazil Serie A         OVER 2.5
# 4                Brazil Serie A             AWAY
# 5                Brazil Serie A             HOME
# 6                Brazil Serie A             DRAW
# 7               Mexico Clausura         OVER 2.5
# 8               Mexico Clausura             AWAY
# 9               Mexico Clausura         OVER 2.5
# 10              Mexico Clausura             HOME
# 11              Mexico Clausura         OVER 2.5
# 12              Mexico Clausura         OVER 2.5
# 13              Mexico Clausura             HOME
# 14              Mexico Clausura        UNDER 2.5
# 15              Mexico Clausura             HOME
# 16                Italy Serie B             DRAW
# 17                Italy Serie B             AWAY
# 18                Italy Serie B             AWAY
# 19                Italy Serie B             AWAY
# 20               France Ligue 1         OVER 2.5
# 21               France Ligue 1             HOME
# 22                      USA MLS         OVER 2.5
# 23                      USA MLS             DRAW
# 24               Brazil Serie A         OVER 2.5
# 25               Brazil Serie A             AWAY
# 26               Brazil Serie A         OVER 2.5
# 27               Brazil Serie A             AWAY
# 28               Brazil Serie A         OVER 2.5
# 29               Brazil Serie A             HOME
# ..                          ...              ...
# 318          Colombia Primera A        UNDER 2.5
# 319          Colombia Primera A             DRAW
# 320          Colombia Primera A         OVER 2.5
# 321          Colombia Primera A             AWAY
# 322          Colombia Primera A             AWAY
# 323            Uruguay Apertura        UNDER 2.5
# 324            Uruguay Apertura             DRAW
# 325            Uruguay Apertura        UNDER 2.5
# 326            Uruguay Apertura             DRAW
# 327            Uruguay Apertura        UNDER 2.5
# 328            Uruguay Apertura             DRAW
# 329            Uruguay Apertura        UNDER 2.5
# 330       Peru Primera Division        UNDER 2.5
# 331       Peru Primera Division        UNDER 2.5
# 332       Peru Primera Division             HOME
# 333                     USA MLS             AWAY
# 334        Argentina Nacional B        UNDER 2.5
# 335        Argentina Nacional B             DRAW
# 336                     USA MLS             DRAW
# 337                     USA MLS             DRAW
# 338                     USA MLS             AWAY
# 339               Spain Segunda             DRAW
# 340  Venezuela Primera Division             DRAW
# 341  Venezuela Primera Division             HOME
# 342          Holland Eredivisie             DRAW
# 343          Holland Eredivisie        UNDER 2.5
# 344              Brazil Serie A             HOME
# 345                     USA MLS         OVER 2.5
# 346                     USA MLS         OVER 2.5
# 347                     USA MLS             HOME
#
# [348 rows x 2 columns]

# %%
# podemos colocar mais filtro dentro de filtro
# queremos agora separar apostas ganhas e perdidas em cada mercado em cada tipo de aposta em cada mercado

fellabot.groupby(['Ganhou a aposta?', 'Mercado', 'Aposta Realizada']).mean()
# Out:
#                                                     Odd  \
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY             4.75
#                                   DRAW             4.81
#                                   HOME             2.84
#                  Over/Under Goals OVER 2.5         2.01
#                                   UNDER 2.5        1.90
# Sim              Match Odds       AWAY             3.73
#                                   DRAW             3.61
#                                   HOME             2.35
#                  Over/Under Goals OVER 2.5         1.98
#                                   UNDER 2.5        1.87
#
#                                                     Valor da Banca No Momento da Entrada  \
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                                            314.58
#                                   DRAW                                            355.42
#                                   HOME                                            339.07
#                  Over/Under Goals OVER 2.5                                        327.02
#                                   UNDER 2.5                                       386.23
# Sim              Match Odds       AWAY                                            303.40
#                                   DRAW                                            346.28
#                                   HOME                                            343.26
#                  Over/Under Goals OVER 2.5                                        305.09
#                                   UNDER 2.5                                       348.79
#
#                                                     Valor da Entrada  \
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                          2.60
#                                   DRAW                          3.04
#                                   HOME                          2.83
#                  Over/Under Goals OVER 2.5                      2.77
#                                   UNDER 2.5                     3.44
# Sim              Match Odds       AWAY                          2.67
#                                   DRAW                          3.00
#                                   HOME                          2.90
#                  Over/Under Goals OVER 2.5                      2.62
#                                   UNDER 2.5                     2.92
#
#                                                     Resultado
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                  -2.60
#                                   DRAW                  -3.04
#                                   HOME                  -2.83
#                  Over/Under Goals OVER 2.5              -2.77
#                                   UNDER 2.5             -3.44
# Sim              Match Odds       AWAY                   7.21
#                                   DRAW                   8.08
#                                   HOME                   3.96
#                  Over/Under Goals OVER 2.5               2.60
#                                   UNDER 2.5              2.62

# %%
# continuando em vez da coluna "Ganhou a aposta?" apenas um print
# essa parte vai do que cada um prefere. mas sempre com o groupby para facilitar

#obs.: ganhas e perdidas aqui é um filtro criado lá em cima

print('ganhas e perdidas\n')
display(fellabot.groupby(['Mercado', 'Aposta Realizada']).mean())

print('perdidas\n')
display(perdidas.groupby(['Mercado', 'Aposta Realizada']).mean())

print('ganhas\n')
display(ganhas.groupby(['Mercado', 'Aposta Realizada']).mean())
# Out:
# ganhas e perdidas
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Mercado          Aposta Realizada
# Match Odds       AWAY             4.51                                311.88
#                  DRAW             4.53                                353.33
#                  HOME             2.66                                340.56
# Over/Under Goals OVER 2.5         2.00                                317.05
#                  UNDER 2.5        1.88                                364.11
#
#                                    Valor da Entrada  Resultado
# Mercado          Aposta Realizada
# Match Odds       AWAY                          2.61      -0.22
#                  DRAW                          3.03      -0.50
#                  HOME                          2.86      -0.41
# Over/Under Goals OVER 2.5                      2.70      -0.33
#                  UNDER 2.5                     3.14       0.14
# perdidas
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Mercado          Aposta Realizada
# Match Odds       AWAY             4.75                                314.58
#                  DRAW             4.81                                355.42
#                  HOME             2.84                                339.07
# Over/Under Goals OVER 2.5         2.01                                327.02
#                  UNDER 2.5        1.90                                386.23
#
#                                    Valor da Entrada  Resultado
# Mercado          Aposta Realizada
# Match Odds       AWAY                          2.60      -2.60
#                  DRAW                          3.04      -3.04
#                  HOME                          2.83      -2.83
# Over/Under Goals OVER 2.5                      2.77      -2.77
#                  UNDER 2.5                     3.44      -3.44
# ganhas
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Mercado          Aposta Realizada
# Match Odds       AWAY             3.73                                303.40
#                  DRAW             3.61                                346.28
#                  HOME             2.35                                343.26
# Over/Under Goals OVER 2.5         1.98                                305.09
#                  UNDER 2.5        1.87                                348.79
#
#                                    Valor da Entrada  Resultado
# Mercado          Aposta Realizada
# Match Odds       AWAY                          2.67       7.21
#                  DRAW                          3.00       8.08
#                  HOME                          2.90       3.96
# Over/Under Goals OVER 2.5                      2.62       2.60
#                  UNDER 2.5                     2.92       2.62

# %%
# usando sum

display(fellabot.groupby(['Mercado', 'Aposta Realizada']).sum())
# Out:
#                                      Odd  \
# Mercado          Aposta Realizada
# Match Odds       AWAY             279.37
#                  DRAW             317.33
#                  HOME             223.72
# Over/Under Goals OVER 2.5         175.73
#                  UNDER 2.5         82.85
#
#                                    Valor da Banca No Momento da Entrada  \
# Mercado          Aposta Realizada
# Match Odds       AWAY                                         19,336.46
#                  DRAW                                         24,733.06
#                  HOME                                         28,607.29
# Over/Under Goals OVER 2.5                                     27,900.58
#                  UNDER 2.5                                    16,020.72
#
#                                    Valor da Entrada  Resultado
# Mercado          Aposta Realizada
# Match Odds       AWAY                           162     -13.86
#                  DRAW                           212     -34.77
#                  HOME                           240     -34.31
# Over/Under Goals OVER 2.5                       238     -29.03
#                  UNDER 2.5                      138       6.12

# %%
display(fellabot.groupby(['Ganhou a aposta?', 'Mercado', 'Aposta Realizada']).agg(['sum', 'mean']))
# Out:
#                                                       Odd       \
#                                                       sum mean
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY             223.39 4.75
#                                   DRAW             259.65 4.81
#                                   HOME             153.32 2.84
#                  Over/Under Goals OVER 2.5          96.42 2.01
#                                   UNDER 2.5         34.13 1.90
# Sim              Match Odds       AWAY              55.98 3.73
#                                   DRAW              57.68 3.61
#                                   HOME              70.40 2.35
#                  Over/Under Goals OVER 2.5          79.31 1.98
#                                   UNDER 2.5         48.72 1.87
#
#                                                    Valor da Banca No Momento da Entrada  \
#                                                                                     sum
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                                        14,785.48
#                                   DRAW                                        19,192.58
#                                   HOME                                        18,309.54
#                  Over/Under Goals OVER 2.5                                    15,697.12
#                                   UNDER 2.5                                    6,952.09
# Sim              Match Odds       AWAY                                         4,550.98
#                                   DRAW                                         5,540.48
#                                   HOME                                        10,297.75
#                  Over/Under Goals OVER 2.5                                    12,203.46
#                                   UNDER 2.5                                    9,068.62
#
#                                                           Valor da Entrada  \
#                                                      mean              sum
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY             314.58              122
#                                   DRAW             355.42              164
#                                   HOME             339.07              153
#                  Over/Under Goals OVER 2.5         327.02              133
#                                   UNDER 2.5        386.23               62
# Sim              Match Odds       AWAY             303.40               40
#                                   DRAW             346.28               48
#                                   HOME             343.26               87
#                  Over/Under Goals OVER 2.5         305.09              105
#                                   UNDER 2.5        348.79               76
#
#                                                         Resultado
#                                                    mean       sum  mean
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY             2.60   -122.00 -2.60
#                                   DRAW             3.04   -164.00 -3.04
#                                   HOME             2.83   -153.00 -2.83
#                  Over/Under Goals OVER 2.5         2.77   -133.00 -2.77
#                                   UNDER 2.5        3.44    -62.00 -3.44
# Sim              Match Odds       AWAY             2.67    108.14  7.21
#                                   DRAW             3.00    129.23  8.08
#                                   HOME             2.90    118.69  3.96
#                  Over/Under Goals OVER 2.5         2.62    103.98  2.60
#                                   UNDER 2.5        2.92     68.12  2.62

# %%
# aqui através do agregation (função agg()) agregamos soma, média e contagem (mais de uma operação) para os campos
# ganhou a aposta?, mercado, aposta realizada. para uns campos faz mais sentido média, para outros
# soma, outros contagem. na documentaçao tem várias outras funções para o agregation (agg())

display(fellabot.groupby(['Ganhou a aposta?', 'Mercado', 'Aposta Realizada']).agg(['sum', 'mean', 'count']))
# Out:
#                                                       Odd             \
#                                                       sum mean count
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY             223.39 4.75    47
#                                   DRAW             259.65 4.81    54
#                                   HOME             153.32 2.84    54
#                  Over/Under Goals OVER 2.5          96.42 2.01    48
#                                   UNDER 2.5         34.13 1.90    18
# Sim              Match Odds       AWAY              55.98 3.73    15
#                                   DRAW              57.68 3.61    16
#                                   HOME              70.40 2.35    30
#                  Over/Under Goals OVER 2.5          79.31 1.98    40
#                                   UNDER 2.5         48.72 1.87    26
#
#                                                    Valor da Banca No Momento da Entrada  \
#                                                                                     sum
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                                        14,785.48
#                                   DRAW                                        19,192.58
#                                   HOME                                        18,309.54
#                  Over/Under Goals OVER 2.5                                    15,697.12
#                                   UNDER 2.5                                    6,952.09
# Sim              Match Odds       AWAY                                         4,550.98
#                                   DRAW                                         5,540.48
#                                   HOME                                        10,297.75
#                  Over/Under Goals OVER 2.5                                    12,203.46
#                                   UNDER 2.5                                    9,068.62
#
#                                                                  \
#                                                      mean count
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY             314.58    47
#                                   DRAW             355.42    54
#                                   HOME             339.07    54
#                  Over/Under Goals OVER 2.5         327.02    48
#                                   UNDER 2.5        386.23    18
# Sim              Match Odds       AWAY             303.40    15
#                                   DRAW             346.28    16
#                                   HOME             343.26    30
#                  Over/Under Goals OVER 2.5         305.09    40
#                                   UNDER 2.5        348.79    26
#
#                                                    Valor da Entrada       \
#                                                                 sum mean
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                          122 2.60
#                                   DRAW                          164 3.04
#                                   HOME                          153 2.83
#                  Over/Under Goals OVER 2.5                      133 2.77
#                                   UNDER 2.5                      62 3.44
# Sim              Match Odds       AWAY                           40 2.67
#                                   DRAW                           48 3.00
#                                   HOME                           87 2.90
#                  Over/Under Goals OVER 2.5                      105 2.62
#                                   UNDER 2.5                      76 2.92
#
#                                                          Resultado
#                                                    count       sum  mean count
# Ganhou a aposta? Mercado          Aposta Realizada
# Não              Match Odds       AWAY                47   -122.00 -2.60    47
#                                   DRAW                54   -164.00 -3.04    54
#                                   HOME                54   -153.00 -2.83    54
#                  Over/Under Goals OVER 2.5            48   -133.00 -2.77    48
#                                   UNDER 2.5           18    -62.00 -3.44    18
# Sim              Match Odds       AWAY                15    108.14  7.21    15
#                                   DRAW                16    129.23  8.08    16
#                                   HOME                30    118.69  3.96    30
#                  Over/Under Goals OVER 2.5            40    103.98  2.60    40
#                                   UNDER 2.5           26     68.12  2.62    26

# %% [markdown]
# ## Taxa de acertos e breakeven odds

# %%
fellabot.head()
# Out:
#                                              Partida        Mandante  \
# 0  https://www.betfellows.com/prognosticos/143252...      Fbc melgar
# 1  https://www.betfellows.com/prognosticos/143265...  Union comercio
# 2  https://www.betfellows.com/prognosticos/143253...   Utc cajamarca
# 3  https://www.betfellows.com/prognosticos/153181...           Ceara
# 4  https://www.betfellows.com/prognosticos/153181...           Ceara
#
#              Visitante Data e Hora da Partida   Data e Hora da Bet Desafio  \
# 0       Sport huancayo    05/05/2019 01:00:00  03/05/2019 04:25:56  Nenhum
# 1          Ayacucho fc    04/05/2019 18:15:00  03/05/2019 04:25:12  Nenhum
# 2  Deportivo municipal    04/05/2019 20:30:00  03/05/2019 04:24:34  Nenhum
# 3     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:05  Nenhum
# 4     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:02  Nenhum
#
#               Campeonato           Mercado Aposta Realizada  Odd  \
# 0  Peru Primera Division  Over/Under Goals        UNDER 2.5 1.80
# 1  Peru Primera Division  Over/Under Goals         OVER 2.5 1.85
# 2  Peru Primera Division  Over/Under Goals         OVER 2.5 2.05
# 3         Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 4         Brazil Serie A        Match Odds             AWAY 2.90
#
#    Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 0                                317.20                 3              Não
# 1                                320.20                 3              Não
# 2                                323.20                 3              Sim
# 3                                326.20                 3              Sim
# 4                                329.20                 3              Sim
#
#    Resultado
# 0      -3.00
# 1      -3.00
# 2       3.15
# 3       3.90
# 4       5.70

# %%
fellabot[['Ganhou a aposta?', 'Resultado']].groupby(['Ganhou a aposta?']).count()
# Out:
#                   Resultado
# Ganhou a aposta?
# Não                     221
# Sim                     127

# %%
fellabot['Resultado'].count()
# Out:
# 348

# %%
acertos_erros = fellabot[['Ganhou a aposta?', 'Resultado']].groupby(['Ganhou a aposta?']).count() / fellabot['Resultado'].count()

# %%
acertos_erros
# Out:
#                   Resultado
# Ganhou a aposta?
# Não                    0.64
# Sim                    0.36

# %%
# odds de vitória para ficar no zero a zero

break_even_odds = 1 / acertos_erros.loc['Sim', 'Resultado'] # poderia colocar esse denominador igual a 0.36 mas to fazendo assim para treinar
print(break_even_odds)
# Out:
# 2.7401574803149606

# %%
# odds médias das vitórias

odds_medias_ganhas = fellabot[fellabot['Ganhou a aposta?'] == 'Sim']['Odd'].mean()
print(odds_medias_ganhas)
# Out:
# 2.45748031496063

# %%
fellabot[['Mercado','Aposta Realizada','Valor da Entrada','Resultado']].groupby(['Mercado','Aposta Realizada']).agg(['count','sum'])
# Out:
#                                   Valor da Entrada      Resultado
#                                              count  sum     count    sum
# Mercado          Aposta Realizada
# Match Odds       AWAY                           62  162        62 -13.86
#                  DRAW                           70  212        70 -34.77
#                  HOME                           84  240        84 -34.31
# Over/Under Goals OVER 2.5                       88  238        88 -29.03
#                  UNDER 2.5                      44  138        44   6.12

# %%
resultado_mercado = fellabot[['Mercado','Aposta Realizada','Valor da Entrada','Resultado']].groupby(['Mercado','Aposta Realizada']).agg(['count','sum'])

# %%
# para calcular o rói tenho que dividir o resultado (lucro e prejuízo) pelo total investido
# a forma de fazer isso é como segue, visto que se trata de multinível ou multidex
# então primeiro selecionamos o que está mais externo (resultado ou valor de entrada)
# e depois o mais interno (sum)

resultado_mercado['Roi mercado'] = resultado_mercado['Resultado']['sum'] / resultado_mercado['Valor da Entrada']['sum']

# %%
resultado_mercado
# Out:
#                                   Valor da Entrada      Resultado         \
#                                              count  sum     count    sum
# Mercado          Aposta Realizada
# Match Odds       AWAY                           62  162        62 -13.86
#                  DRAW                           70  212        70 -34.77
#                  HOME                           84  240        84 -34.31
# Over/Under Goals OVER 2.5                       88  238        88 -29.03
#                  UNDER 2.5                      44  138        44   6.12
#
#                                   Roi mercado
#
# Mercado          Aposta Realizada
# Match Odds       AWAY                   -0.09
#                  DRAW                   -0.16
#                  HOME                   -0.14
# Over/Under Goals OVER 2.5               -0.12
#                  UNDER 2.5               0.04

# %%
# o valor do roi acima está em percentual e por mercado
# agora vamos calcular o roi total

resultado_mercado['Roi total'] = resultado_mercado['Resultado']['sum'] / resultado_mercado['Valor da Entrada']['sum'].sum()

# %%
resultado_mercado
# Out:
#                                   Valor da Entrada      Resultado         \
#                                              count  sum     count    sum
# Mercado          Aposta Realizada
# Match Odds       AWAY                           62  162        62 -13.86
#                  DRAW                           70  212        70 -34.77
#                  HOME                           84  240        84 -34.31
# Over/Under Goals OVER 2.5                       88  238        88 -29.03
#                  UNDER 2.5                      44  138        44   6.12
#
#                                   Roi mercado Roi total
#
# Mercado          Aposta Realizada
# Match Odds       AWAY                   -0.09     -0.01
#                  DRAW                   -0.16     -0.04
#                  HOME                   -0.14     -0.03
# Over/Under Goals OVER 2.5               -0.12     -0.03
#                  UNDER 2.5               0.04      0.01

# %%
# vamos fazer a mesma coisa que fizemos em cima só que usando loc agora
# só para fixar mais uma forma de fazer
# os ":" abaixo é pq queremos todas as linhas

resultado_mercado['Entradas % total'] = resultado_mercado.loc[:,('Valor da Entrada','sum')] / resultado_mercado.loc[:,('Valor da Entrada','sum')].sum()

# %%
resultado_mercado
# Out:
#                                   Valor da Entrada      Resultado         \
#                                              count  sum     count    sum
# Mercado          Aposta Realizada
# Match Odds       AWAY                           62  162        62 -13.86
#                  DRAW                           70  212        70 -34.77
#                  HOME                           84  240        84 -34.31
# Over/Under Goals OVER 2.5                       88  238        88 -29.03
#                  UNDER 2.5                      44  138        44   6.12
#
#                                   Roi mercado Roi total Entradas % total
#
# Mercado          Aposta Realizada
# Match Odds       AWAY                   -0.09     -0.01             0.16
#                  DRAW                   -0.16     -0.04             0.21
#                  HOME                   -0.14     -0.03             0.24
# Over/Under Goals OVER 2.5               -0.12     -0.03             0.24
#                  UNDER 2.5               0.04      0.01             0.14

# %%
fellabot.head()
# Out:
#                                              Partida        Mandante  \
# 0  https://www.betfellows.com/prognosticos/143252...      Fbc melgar
# 1  https://www.betfellows.com/prognosticos/143265...  Union comercio
# 2  https://www.betfellows.com/prognosticos/143253...   Utc cajamarca
# 3  https://www.betfellows.com/prognosticos/153181...           Ceara
# 4  https://www.betfellows.com/prognosticos/153181...           Ceara
#
#              Visitante Data e Hora da Partida   Data e Hora da Bet Desafio  \
# 0       Sport huancayo    05/05/2019 01:00:00  03/05/2019 04:25:56  Nenhum
# 1          Ayacucho fc    04/05/2019 18:15:00  03/05/2019 04:25:12  Nenhum
# 2  Deportivo municipal    04/05/2019 20:30:00  03/05/2019 04:24:34  Nenhum
# 3     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:05  Nenhum
# 4     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:02  Nenhum
#
#               Campeonato           Mercado Aposta Realizada  Odd  \
# 0  Peru Primera Division  Over/Under Goals        UNDER 2.5 1.80
# 1  Peru Primera Division  Over/Under Goals         OVER 2.5 1.85
# 2  Peru Primera Division  Over/Under Goals         OVER 2.5 2.05
# 3         Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 4         Brazil Serie A        Match Odds             AWAY 2.90
#
#    Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 0                                317.20                 3              Não
# 1                                320.20                 3              Não
# 2                                323.20                 3              Sim
# 3                                326.20                 3              Sim
# 4                                329.20                 3              Sim
#
#    Resultado
# 0      -3.00
# 1      -3.00
# 2       3.15
# 3       3.90
# 4       5.70

# %%
fellabot.groupby('Campeonato').sum().sort_values('Resultado')
# Out:
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Campeonato
# Italy Serie A                    55.50                              8,192.47
# Spain Primera Liga               51.13                              5,032.58
# Mexico Clausura                  87.35                             11,083.37
# Turkey Super Lig                 24.44                              4,078.36
# USA MLS                         104.22                             14,644.40
# Colombia Primera A               85.88                             11,719.65
# Germany Bundesliga II            33.68                              3,056.59
# France Ligue 2                   82.00                              7,694.05
# Germany Bundesliga I             32.84                              2,538.32
# Mexico Liga de Ascenso Clausura   5.95                                875.37
# Peru Primera Division            14.40                              2,274.08
# Italy Serie B                    64.97                              5,441.41
# Brazil Serie B                   17.41                              2,034.40
# Chile Primera Division            3.96                                307.63
# Spain Segunda                     5.15                                722.37
# France Ligue 1                   37.14                              3,997.06
# Portugal Primeira Liga           19.73                              2,641.64
# Argentina Nacional B              9.45                              1,763.50
# Venezuela Primera Division       13.55                              1,690.29
# England Championship            106.86                             10,199.71
# England Premier League           69.41                              3,585.91
# Holland Eredivisie               82.30                              4,304.70
# Brazil Serie A                   47.61                              5,074.93
# Uruguay Apertura                 24.11                              3,645.31
#
#                                  Valor da Entrada  Resultado
# Campeonato
# Italy Serie A                                  72     -29.46
# Spain Primera Liga                             44     -29.00
# Mexico Clausura                                93     -28.74
# Turkey Super Lig                               33     -21.23
# USA MLS                                       133     -12.90
# Colombia Primera A                            101     -11.59
# Germany Bundesliga II                          20     -10.26
# France Ligue 2                                 60      -9.00
# Germany Bundesliga I                           18      -8.00
# Mexico Liga de Ascenso Clausura                 8      -8.00
# Peru Primera Division                          21      -6.45
# Italy Serie B                                  44      -5.50
# Brazil Serie B                                 14      -4.60
# Chile Primera Division                          3      -3.00
# Spain Segunda                                   6      -1.60
# France Ligue 1                                 32      -0.55
# Portugal Primeira Liga                         25       3.14
# Argentina Nacional B                           16       3.50
# Venezuela Primera Division                     14       5.20
# England Championship                           87       7.63
# England Premier League                         31      11.54
# Holland Eredivisie                             36      16.15
# Brazil Serie A                                 45      16.21
# Uruguay Apertura                               34      20.65

# %%
fellabot_campeonatos = fellabot.groupby('Campeonato').sum().sort_values('Resultado')
fellabot_campeonatos_prejuizo = fellabot_campeonatos[fellabot_campeonatos['Resultado'] < 0]

print('O resultado foi de $BC{:.2f}'.format(fellabot['Resultado'].sum())) # lembrando q ta somando tanto os lucros como prejuizo fazendo essa soma assim
display(fellabot_campeonatos_prejuizo)
# Out:
# O resultado foi de $BC-105.84
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Campeonato
# Italy Serie A                    55.50                              8,192.47
# Spain Primera Liga               51.13                              5,032.58
# Mexico Clausura                  87.35                             11,083.37
# Turkey Super Lig                 24.44                              4,078.36
# USA MLS                         104.22                             14,644.40
# Colombia Primera A               85.88                             11,719.65
# Germany Bundesliga II            33.68                              3,056.59
# France Ligue 2                   82.00                              7,694.05
# Germany Bundesliga I             32.84                              2,538.32
# Mexico Liga de Ascenso Clausura   5.95                                875.37
# Peru Primera Division            14.40                              2,274.08
# Italy Serie B                    64.97                              5,441.41
# Brazil Serie B                   17.41                              2,034.40
# Chile Primera Division            3.96                                307.63
# Spain Segunda                     5.15                                722.37
# France Ligue 1                   37.14                              3,997.06
#
#                                  Valor da Entrada  Resultado
# Campeonato
# Italy Serie A                                  72     -29.46
# Spain Primera Liga                             44     -29.00
# Mexico Clausura                                93     -28.74
# Turkey Super Lig                               33     -21.23
# USA MLS                                       133     -12.90
# Colombia Primera A                            101     -11.59
# Germany Bundesliga II                          20     -10.26
# France Ligue 2                                 60      -9.00
# Germany Bundesliga I                           18      -8.00
# Mexico Liga de Ascenso Clausura                 8      -8.00
# Peru Primera Division                          21      -6.45
# Italy Serie B                                  44      -5.50
# Brazil Serie B                                 14      -4.60
# Chile Primera Division                          3      -3.00
# Spain Segunda                                   6      -1.60
# France Ligue 1                                 32      -0.55

# %%
fellabot_campeonatos_prejuizo['Acumulado'] = fellabot_campeonatos_prejuizo['Resultado'].cumsum()
fellabot_campeonatos_prejuizo['% Acumulado'] = fellabot_campeonatos_prejuizo['Acumulado'] / fellabot_campeonatos_prejuizo['Resultado'].sum()
display(fellabot_campeonatos_prejuizo)
# Out:
# /home/andre/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/andre/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    Odd  Valor da Banca No Momento da Entrada  \
# Campeonato
# Italy Serie A                    55.50                              8,192.47
# Spain Primera Liga               51.13                              5,032.58
# Mexico Clausura                  87.35                             11,083.37
# Turkey Super Lig                 24.44                              4,078.36
# USA MLS                         104.22                             14,644.40
# Colombia Primera A               85.88                             11,719.65
# Germany Bundesliga II            33.68                              3,056.59
# France Ligue 2                   82.00                              7,694.05
# Germany Bundesliga I             32.84                              2,538.32
# Mexico Liga de Ascenso Clausura   5.95                                875.37
# Peru Primera Division            14.40                              2,274.08
# Italy Serie B                    64.97                              5,441.41
# Brazil Serie B                   17.41                              2,034.40
# Chile Primera Division            3.96                                307.63
# Spain Segunda                     5.15                                722.37
# France Ligue 1                   37.14                              3,997.06
#
#                                  Valor da Entrada  Resultado  Acumulado  \
# Campeonato
# Italy Serie A                                  72     -29.46     -29.46
# Spain Primera Liga                             44     -29.00     -58.46
# Uruguay Apertura                               34      20.65

# %%
print('após a remoção de alguns campeonatos, o resultado do fellabot em $BC seria de {:.2f}'.format(fellabot_campeonatos['Resultado'].sum()))
# Out:
# após a remoção de alguns campeonatos, o resultado do fellabot em $BC seria de 2.59

# %% [markdown]
# ## Separando intervalos de odds para ver os mais e menos lucrativos

# %%
fellabot.describe()
# Out:
#          Odd  Valor da Banca No Momento da Entrada  Valor da Entrada  \
# count 348.00                                348.00            348.00
# mean    3.10                                335.05              2.84
# std     1.90                                 77.12              0.85
# min     1.44                                172.63              1.00
# 25%     1.96                                280.07              2.00
# 50%     2.33                                342.59              3.00
# 75%     3.66                                394.61              3.00
# max    14.50                                477.82              4.00
#
#        Resultado
# count     348.00
# mean       -0.30
# std         4.11
# min        -4.00
# 25%        -3.00
# 50%        -2.00
# 75%         2.20
# max        28.50

# %%
# agrupando odds por intervalos de odds com o método cut()

pd.cut(fellabot['Odd'], [1,1.25,1.5,1.75,2,2.25,2.50,3,4,5,7,10,14.5])
# Out:
# 0      (1.75, 2.0]
# 1      (1.75, 2.0]
# 2      (2.0, 2.25]
# 3      (2.25, 2.5]
# 4       (2.5, 3.0]
# 5      (1.5, 1.75]
# 6       (3.0, 4.0]
# 7      (1.75, 2.0]
# 8       (5.0, 7.0]
# 9      (1.75, 2.0]
# 10     (1.5, 1.75]
# 11     (2.0, 2.25]
# 12     (1.75, 2.0]
# 13     (1.5, 1.75]
# 14     (2.0, 2.25]
# 15      (5.0, 7.0]
# 16      (5.0, 7.0]
# 17      (5.0, 7.0]
# 18      (2.5, 3.0]
# 19      (3.0, 4.0]
# 20     (1.5, 1.75]
# 21      (3.0, 4.0]
# 22     (1.5, 1.75]
# 23      (3.0, 4.0]
# 24     (2.0, 2.25]
# 25      (2.5, 3.0]
# 26     (2.0, 2.25]
# 27     (7.0, 10.0]
# 28     (2.25, 2.5]
# 29     (7.0, 10.0]
#           ...
# 318    (1.5, 1.75]
# 319     (3.0, 4.0]
# 320    (2.0, 2.25]
# 321     (5.0, 7.0]
# 322     (2.5, 3.0]
# 323    (2.0, 2.25]
# 324     (3.0, 4.0]
# 325    (2.0, 2.25]
# 326     (4.0, 5.0]
# 327    (2.0, 2.25]
# 328     (3.0, 4.0]
# 329    (2.25, 2.5]
# 330    (1.75, 2.0]
# 331    (2.0, 2.25]
# 332     (4.0, 5.0]
# 333     (3.0, 4.0]
# 334    (1.25, 1.5]
# 335     (3.0, 4.0]
# 336     (4.0, 5.0]
# 337     (4.0, 5.0]
# 338     (5.0, 7.0]
# 339     (2.5, 3.0]
# 340     (3.0, 4.0]
# 341     (3.0, 4.0]
# 342     (3.0, 4.0]
# 343    (2.25, 2.5]
# 344    (1.5, 1.75]
# 345    (1.5, 1.75]
# 346    (1.5, 1.75]
# 347    (1.25, 1.5]
# Name: Odd, Length: 348, dtype: category
# Categories (12, interval[float64]): [(1.0, 1.25] < (1.25, 1.5] < (1.5, 1.75] < (1.75, 2.0] ... (4.0, 5.0] < (5.0, 7.0] < (7.0, 10.0] < (10.0, 14.5]]

# %%
fellabot['odds_bin'] = pd.cut(fellabot['Odd'], [1,1.25,1.5,1.75,2,2.25,2.50,3,4,5,7,10,14.5])
fellabot.head()
# Out:
#                                              Partida        Mandante  \
# 0  https://www.betfellows.com/prognosticos/143252...      Fbc melgar
# 1  https://www.betfellows.com/prognosticos/143265...  Union comercio
# 2  https://www.betfellows.com/prognosticos/143253...   Utc cajamarca
# 3  https://www.betfellows.com/prognosticos/153181...           Ceara
# 4  https://www.betfellows.com/prognosticos/153181...           Ceara
#
#              Visitante Data e Hora da Partida   Data e Hora da Bet Desafio  \
# 0       Sport huancayo    05/05/2019 01:00:00  03/05/2019 04:25:56  Nenhum
# 1          Ayacucho fc    04/05/2019 18:15:00  03/05/2019 04:25:12  Nenhum
# 2  Deportivo municipal    04/05/2019 20:30:00  03/05/2019 04:24:34  Nenhum
# 3     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:05  Nenhum
# 4     Atletico mineiro    05/05/2019 00:00:00  03/05/2019 04:20:02  Nenhum
#
#               Campeonato           Mercado Aposta Realizada  Odd  \
# 0  Peru Primera Division  Over/Under Goals        UNDER 2.5 1.80
# 1  Peru Primera Division  Over/Under Goals         OVER 2.5 1.85
# 2  Peru Primera Division  Over/Under Goals         OVER 2.5 2.05
# 3         Brazil Serie A  Over/Under Goals         OVER 2.5 2.30
# 4         Brazil Serie A        Match Odds             AWAY 2.90
#
#    Valor da Banca No Momento da Entrada  Valor da Entrada Ganhou a aposta?  \
# 0                                317.20                 3              Não
# 1                                320.20                 3              Não
# 2                                323.20                 3              Sim
# 3                                326.20                 3              Sim
# 4                                329.20                 3              Sim
#
#    Resultado     odds_bin
# 0      -3.00  (1.75, 2.0]
# 1      -3.00  (1.75, 2.0]
# 2       3.15  (2.0, 2.25]
# 3       3.90  (2.25, 2.5]
# 4       5.70   (2.5, 3.0]

# %%
fellabot.groupby(['odds_bin']).sum().sort_values('Resultado')
# Out:
#                 Odd  Valor da Banca No Momento da Entrada  Valor da Entrada  \
# odds_bin
# (3.0, 4.0]   216.36                             21,143.20               182
# (1.5, 1.75]   82.77                             16,943.94               145
# (5.0, 7.0]   131.00                              6,935.63                56
# (2.0, 2.25]  130.35                             20,335.34               170
# (1.25, 1.5]   16.24                              3,686.63                33
# (7.0, 10.0]   79.80                              3,188.10                27
# (4.0, 5.0]   109.00                              8,430.24                72
# (1.75, 2.0]   68.45                             11,485.45                97
# (2.5, 3.0]    93.00                             10,772.61                90
# (1.0, 1.25]    0.00                                  0.00                 0
# (2.25, 2.5]   80.05                             11,708.54               100
# (10.0, 14.5]  72.00                              1,968.42                18
#
#               Resultado
# odds_bin
# (3.0, 4.0]       -28.05
# (1.5, 1.75]      -24.95
# (5.0, 7.0]       -20.45
# (2.0, 2.25]      -17.84
# (1.25, 1.5]      -12.21
# (7.0, 10.0]      -12.00
# (4.0, 5.0]       -11.92
# (1.75, 2.0]       -4.77
# (2.5, 3.0]        -0.20
# (1.0, 1.25]        0.00
# (2.25, 2.5]       13.05
# (10.0, 14.5]      13.50
