# %%
# Aqui mesmo a página usando javascript conseguimos fazer web scraping 
# para isso usamos o selenium

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import csv

# descomentar estas 4 próximas linhas para usar o navegador invisível
#gecko = '/home/andre/Downloads/geckodriver'
#driver = webdriver.FirefoxOptions()
#driver.add_argument('-headless')
#driver = webdriver.Firefox(executable_path=gecko, options=driver)

def scanner(pais, campeonato, ano, rod, cont_rod):

    possebola = 'Posse de bola'
    chutes = 'Finalizações'
    chutesnogol = 'Finalizações no gol'
    chutesforagol = 'Finalizações para fora'
    chutesbloqueados = 'Chutes travados'
    corner = 'Escanteios'
    impedimentos = 'Impedimentos'
    faltas = 'Faltas'
    cartoesa = 'Cartões amarelos'
    cartoesv = 'Cartões vermelhos'
    grandeschances = 'Grandes oportunidades'
    grandeschancesperdidas = 'Grandes chances perdidas'
    chutesnatrave = 'Chute na trave'
    contraataques = 'Contra-ataques'
    chutesdentroarea = 'Finalizações de dentro da área'
    chutesforaarea = 'Finalizações de fora da área'
    defesasgoleiro = 'Defesas do goleiro'
    passes = 'Passes'
    passescertos = 'Prec. passes'
    bolaslongas = 'Bolas longas'
    cruza = 'Cruzamentos'
    dribles = 'Dribles'
    posseperdida = 'Possession lost'
    duelosganhos = 'Duelos ganhos'
    disputasaereasvencidas = 'Disputas aéreas vencidas'
    desarmes = 'Desarmes'
    intercept = 'Interceptações'
    distancias = 'Distâncias'

    html = driver.execute_script("return document.documentElement.outerHTML")
    page = bs(html, 'html.parser')

    # contando o número de jogos da rodada 
    
    # auxiliar para pegar apenas o número da rodada e não a string "RODADA X"
    aux_rod = rod.split(' ')[1] 
    
    tam = len(page.find('',{'class':'styles__EventListContent-b3g57w-2 jPsaDp'}).find_all('a')) - 1
   
    rodada = rod.split(' ')[1]
    print(f'Essa rodada tem {tam} jogos')
    
    
    
    # inicialização de variáveis
    golscasaht = ''
    golsvisitanteht = ''
    golscasaft = ''
    golsvisitanteft = ''
    resultadoht = ''
    resultadoft = ''
    totalgolsht = ''
    totalgolsft = ''
    vencedorht = ''
    vencedorft = ''
    possebolacasaft = ''
    possebolavisitanteft = ''
    possebolacasaht = ''
    possebolavisitanteht = ''
    chutescasaft = ''
    chutesvisitanteft = ''
    chutescasaht = ''
    chutesvisitanteht = ''
    chutesnogolcasaft = ''
    chutesnogolvisitanteft = ''
    chutesnogolcasaht = ''
    chutesnogolvisitanteht = ''
    chutesforagolcasaft = ''
    chutesforagolvisitanteft = ''
    chutesforagolcasaht = ''
    chutesforagolvisitanteht = ''
    chutesbloqueadoscasaft = ''
    chutesbloqueadosvisitanteft = ''
    chutesbloqueadoscasaht = ''
    chutesbloqueadosvisitanteht = ''
    cornercasaft = ''
    cornervisitanteft = ''
    cornercasaht = ''
    cornervisitanteht = ''
    impedimentoscasaft = ''
    impedimentosvisitanteft = ''
    impedimentoscasaht = ''
    impedimentosvisitanteht = ''
    faltascasaft = ''
    faltasvisitanteft = ''
    faltascasaht = ''
    faltasvisitanteht = ''
    cartoesacasaft = ''
    cartoesavisitanteft = ''
    cartoesacasaht = ''
    cartoesavisitanteht = ''
    cartoesvcasaft = ''
    cartoesvvisitanteft = ''
    cartoesvcasaht = ''
    cartoesvvisitanteht = ''
    grandeschancescasaft = ''
    grandeschancesvisitanteft = ''
    grandeschancescasaht = ''
    grandeschancesvisitanteht = ''
    grandeschancesperdidascasaft = ''
    grandeschancesperdidasvisitanteft = ''
    grandeschancesperdidascasaht = ''
    grandeschancesperdidasvisitanteht = ''
    chutesnatravecasaft = ''
    chutesnatravevisitanteft = ''
    chutesnatravecasaht = ''
    chutesnatravevisitanteht = ''
    contraataquescasaft = ''
    contraataquesvisitanteft = ''
    contraataquescasaht = ''
    contraataquesvisitanteht = ''
    chutesdentroareacasaft = ''
    chutesdentroareavisitanteft = ''
    chutesdentroareacasaht = ''
    chutesdentroareavisitanteht = ''
    chutesforaareacasaft = ''
    chutesforaareavisitanteft = ''
    chutesforaareacasaht = ''
    chutesforaareavisitanteht = ''
    defesasgoleirocasaft = ''
    defesasgoleirovisitanteft = ''
    defesasgoleirocasaht = ''
    defesasgoleirovisitanteht = ''
    passescasaft = ''
    passesvisitanteft = ''
    passescasaht = ''
    passesvisitanteht = ''
    passescertoscasaft = ''
    passescertosvisitanteft = ''
    passescertoscasaht = ''
    passescertosvisitanteht = ''
    bolaslongascasaft = ''
    bolaslongasvisitanteft = ''
    bolaslongascasaht = ''
    bolaslongasvisitanteht = ''
    cruzacasaft = ''
    cruzavisitanteft = ''
    cruzacasaht = ''
    cruzavisitanteht = ''
    driblescasaft = ''
    driblesvisitanteft = ''
    driblescasaht = ''
    driblesvisitanteht = ''
    posseperdidacasaft = ''
    posseperdidavisitanteft = ''
    posseperdidacasaht = ''
    posseperdidavisitanteht = ''
    duelosganhoscasaft = ''
    duelosganhosvisitanteft = ''
    duelosganhoscasaht = ''
    duelosganhosvisitanteht = ''
    disputasaereasvencidascasaft = ''
    disputasaereasvencidasvisitanteft = ''
    disputasaereasvencidascasaht = ''
    disputasaereasvencidasvisitanteht = ''
    desarmescasaft = ''
    desarmesvisitanteft = ''
    desarmescasaht = ''
    desarmesvisitanteht = ''
    interceptcasaft = ''
    interceptvisitanteft = ''
    interceptcasaht = ''
    interceptvisitanteht = ''
    distanciascasaft = ''
    distanciasvisitanteft = ''
    distanciascasaht = ''
    distanciasvisitanteht = ''

    
    
    # Percorrendo todos os jogos da rodada
    for j in range(tam):
        try:
            html = driver.execute_script("return document.documentElement.outerHTML")
            page = bs(html, 'html.parser')
            
            print(f'rodada {rodada} jogo {j + 1}')

            mingol = []
            resultadopormin = []
            placar_ord = []
            min_ord = []
            resultadomin = []
            goltime = []
            golxtime_casamin = []
            golxtime_visitantemin = []

            # clicando nos jogos
            incrementa_jogos = str(j + 2)
            
            for tente_outra_vez in range(4):
                try:
                    # clicando nos jogos                                                    
                    driver.find_element_by_css_selector('a.EventCellstyles__Link-sc-1m83enb-0:nth-child(' + incrementa_jogos + ')').click()                                 
                    time.sleep(4)
                   
                    # pegando o nome dos times 
                                                   
                    time_casa = ''  
                    time_visitante = ''                                                                                                             
                    time_casa = driver.find_element_by_css_selector('.styles__EventLink-d389b-0').text.strip().split(' - ')[0]
                    time_visitante = driver.find_element_by_css_selector('.styles__EventLink-d389b-0').text.strip().split(' - ')[1]
                    break                    
                except:
                    continue     
                    
            # verificando se a partida possui dados ht e ft
            teste_estatistica = ''  
            teste_cancelado = ''
            teste_estatistica = driver.find_element_by_css_selector('.fYkgJo > a:nth-child(2)').text.strip()
            try:
                # verificando se a partida não está cancelada
                teste_cancelado = page.find('',{'class':'styles__EventListContent-b3g57w-2 jPsaDp'}).find_all('a')[j+1].find('',{'class':'Content-sc-1o55eay-0 EventCellstyles__StatusInfo-ni00fg-2 gCrydF'}).text.strip()
                continue
            except:
                pass
            
            # testando se a partida possui estatísticas
            if (teste_estatistica == 'ESTATÍSTICAS'):
                # se chegou aqui é porque a partida possui dados ht e ft
                # clica em estatísticas
                driver.find_element_by_css_selector('.fYkgJo > a:nth-child(2)').click()
                time.sleep(3)                                
            else:
                continue

            # Coletando informações do jogo                                 
            resultadoft = driver.find_element_by_css_selector('.styles__StyledResult-sc-171us6i-3').text.strip()
            time.sleep(1)
            resultadoft = resultadoft[0] + 'x' + resultadoft[4] 
            golscasaft = resultadoft[0]                       
            golsvisitanteft = resultadoft[2]
           
            resultadoht = driver.find_element_by_css_selector('.styles__CenterSection-sc-171us6i-2 > div:nth-child(2)').text.strip()
            resultadoht = resultadoht[1] + 'x' + resultadoht[5]
            golscasaht = resultadoht[0]
            golsvisitanteht = resultadoht[2]
            golscasa2t = int(golscasaft) - int(golscasaht)
            golsvisitante2t = int(golsvisitanteft) - int(golsvisitanteht) 
            
            totalgolsht = int(golscasaht) + int(golsvisitanteht)
            totalgolsft = int(golscasaft) + int(golsvisitanteft)

            if int(golscasaht) > int(golsvisitanteht):
                vencedorht = 'H'
            elif int(golscasaht) < int(golsvisitanteht):
                vencedorht = 'A'
            else:
                vencedorht = 'D'
                
            if int(golscasaft) > int(golsvisitanteft):
                vencedorft = 'H'
            elif int(golscasaft) < int(golsvisitanteft):
                vencedorft = 'A'
            else:
                vencedorft = 'D'

            print(pais)                             
            print(campeonato)
            print(ano)
            print(time_casa)
            print(time_visitante)
            
            print(f'golscasaht {golscasaht}')
            print(f'golsvisitanteht {golsvisitanteht}')
            print(f'golscasaft {golscasaft}')
            print(f'golsvisitanteft {golsvisitanteft}')
            print(f'resultado ht {resultadoht}')
            print(f'resultado ft {resultadoft}')
            print(f'total de gols ht {totalgolsht}') 
            print(f'total de gols ft {totalgolsft}')
            print(f'vencedor ht {vencedorht}')
            print(f'vencedor ft {vencedorft}')
            
            # rolar a página mais para baixo
            body = driver.find_element_by_css_selector('body')
            body.send_keys(Keys.PAGE_DOWN)
            time.sleep(1) 
            
            

            # Pegando as estatísticas de cada jogo no ft, ht e 2o tempo
            
            html = driver.execute_script("return document.documentElement.outerHTML")
            page = bs(html, 'html.parser')
            time.sleep(1)
            
            for intervalos in range(2): # colocar 3 no range se for pegar dados do 2o tempo também
                try:
                    if intervalos == 0:
                        # pegando trecho de código necessário de uma vez
                        # para não ter que ficar rolando a página
                        trecho_codigo = page.find_all('',{'class':'Tabs__Content-vifb7j-1 jppjfQ'})[2]
                        tam_blocos = len(trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'}))
                        
                        # quantidade de dados ft
                        # scaneando os dados
                        for tam_blocos1 in range(tam_blocos):
                    
                            nome_dado = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[1].find('div').text.strip()                

                            if nome_dado.strip() == possebola:

                                possebolacasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                    
                                possebolavisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                    
                                print(nome_dado)
                                print(possebolacasaft)  
                                print(possebolavisitanteft) 

                            elif nome_dado.strip() == chutes:

                                chutescasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutescasaft)  
                                print(chutesvisitanteft)  
                                
                            elif nome_dado.strip() == chutesnogol:

                                chutesnogolcasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesnogolvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                
                                print(nome_dado)
                                print(chutesnogolcasaft)  
                                print(chutesnogolvisitanteft)  
                            
                            elif nome_dado.strip() == chutesforagol:

                                chutesforagolcasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesforagolvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                
                                print(nome_dado)
                                print(chutesforagolcasaft)  
                                print(chutesforagolvisitanteft)  
                            
                            elif nome_dado.strip() == chutesbloqueados:

                                chutesbloqueadoscasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesbloqueadosvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesbloqueadoscasaft)  
                                print(chutesbloqueadosvisitanteft)  
                                
                            elif nome_dado.strip() == corner: 

                                cornercasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cornervisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cornercasaft)  
                                print(cornervisitanteft)  
                                
                            elif nome_dado.strip() == impedimentos:

                                impedimentoscasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                impedimentosvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(impedimentoscasaft)  
                                print(impedimentosvisitanteft)  
                                
                            elif nome_dado.strip() == faltas:

                                faltascasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                faltasvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(faltascasaft)  
                                print(faltasvisitanteft) 
                                
                            elif nome_dado.strip() == cartoesa:

                                cartoesacasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cartoesavisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cartoesacasaft)  
                                print(cartoesavisitanteft) 
                                
                            elif nome_dado.strip() == cartoesv:

                                cartoesvcasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cartoesvvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cartoesvcasaft)  
                                print(cartoesvvisitanteft) 
                                
                            elif nome_dado.strip() == grandeschances:

                                grandeschancescasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                grandeschancesvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(grandeschancescasaft)  
                                print(grandeschancesvisitanteft) 
                                
                            elif nome_dado.strip() == grandeschancesperdidas:

                                grandeschancesperdidascasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                grandeschancesperdidasvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(grandeschancesperdidascasaft)  
                                print(grandeschancesperdidasvisitanteft) 
                                
                            elif nome_dado.strip() == chutesnatrave:

                                chutesnatravecasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesnatravevisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesnatravecasaft)  
                                print(chutesnatravevisitanteft) 
                                
                            elif nome_dado.strip() == contraataques:

                                contraataquescasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                contraataquesvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(contraataquescasaft)  
                                print(contraataquesvisitanteft) 
                                
                            elif nome_dado.strip() == chutesdentroarea:

                                chutesdentroareacasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesdentroareavisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesdentroareacasaft)  
                                print(chutesdentroareavisitanteft) 
                                
                            elif nome_dado.strip() == chutesforaarea:

                                chutesforaareacasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesforaareavisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesforaareacasaft)  
                                print(chutesforaareavisitanteft) 
                                
                            elif nome_dado.strip() == defesasgoleiro:

                                defesasgoleirocasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                defesasgoleirovisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(defesasgoleirocasaft)  
                                print(defesasgoleirovisitanteft) 
                                
                            elif nome_dado.strip() == passes:

                                passescasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                passesvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(passescasaft)  
                                print(passesvisitanteft) 
                                
                            elif nome_dado.strip() == passescertos:

                                passescertoscasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip().split('(')[1].split('%')[0]
                                passescertosvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip().split('(')[1].split('%')[0]

                                print(nome_dado)
                                print(passescertoscasaft)  
                                print(passescertosvisitanteft)
                           
                                
                            elif nome_dado.strip() == bolaslongas:

                                bolaslongascasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                bolaslongasvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(bolaslongascasaft)  
                                print(bolaslongasvisitanteft) 
                                
                            elif nome_dado.strip() == cruza:

                                cruzacasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cruzavisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cruzacasaft)  
                                print(cruzavisitanteft) 
                                
                            elif nome_dado.strip() == dribles:

                                driblescasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                driblesvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(driblescasaft)  
                                print(driblesvisitanteft) 
                                
                            elif nome_dado.strip() == posseperdida:

                                posseperdidacasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                posseperdidavisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(posseperdidacasaft)  
                                print(posseperdidavisitanteft) 
                                
                            elif nome_dado.strip() == duelosganhos:

                                duelosganhoscasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                duelosganhosvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(duelosganhoscasaft)  
                                print(duelosganhosvisitanteft) 
                                
                            elif nome_dado.strip() == disputasaereasvencidas:

                                disputasaereasvencidascasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                disputasaereasvencidasvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(disputasaereasvencidascasaft)  
                                print(disputasaereasvencidasvisitanteft) 
                                
                            elif nome_dado.strip() == desarmes:

                                desarmescasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                desarmesvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(desarmescasaft)  
                                print(desarmesvisitanteft) 
                                
                            elif nome_dado.strip() == intercept:

                                interceptcasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                interceptvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(interceptcasaft)  
                                print(interceptvisitanteft) 
                                
                            elif nome_dado.strip() == distancias:

                                distanciascasaft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                distanciasvisitanteft = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()            

                                print(nome_dado)
                                print(distanciascasaft)  
                                print(distanciastvisitanteft)
                                
                    elif intervalos == 1:                                  
                        # obtendo dados 1o tempo do jogo                  
                        driver.find_element_by_css_selector('div.Tab__Wrapper-sc-1v9c4xe-0:nth-child(2) > div:nth-child(1) > div:nth-child(1) > a:nth-child(2)').click()
                        time.sleep(1)
                        
                        html = driver.execute_script("return document.documentElement.outerHTML")
                        page = bs(html, 'html.parser')
                        
                        trecho_codigo = page.find_all('',{'class':'Tabs__Content-vifb7j-1 jppjfQ'})[2]
                        time.sleep(1)

                        tam_blocos = len(trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'}))
                        
                        # scaneando os dados
                        for tam_blocos1 in range(tam_blocos):
                           
                            nome_dado = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[1].find('div').text.strip()
                            
                            if nome_dado.strip() == possebola:
                                
                                possebolacasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                possebolavisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(possebolacasaht)  
                                print(possebolavisitanteht)  

                            elif nome_dado.strip() == chutes:

                                chutescasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutescasaht)  
                                print(chutesvisitanteht)  
                                
                            elif nome_dado.strip() == chutesnogol:

                                chutesnogolcasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesnogolvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                
                                print(nome_dado)
                                print(chutesnogolcasaht)  
                                print(chutesnogolvisitanteht)  
                            
                            elif nome_dado.strip() == chutesforagol:

                                chutesforagolcasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesforagolvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                
                                print(nome_dado)
                                print(chutesforagolcasaht)  
                                print(chutesforagolvisitanteht)  
                            
                            elif nome_dado.strip() == chutesbloqueados:

                                chutesbloqueadoscasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesbloqueadosvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesbloqueadoscasaht)  
                                print(chutesbloqueadosvisitanteht)  
                                
                            elif nome_dado.strip() == corner: 

                                cornercasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cornervisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cornercasaht)  
                                print(cornervisitanteht)  
                                
                            elif nome_dado.strip() == impedimentos:

                                impedimentoscasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                impedimentosvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(impedimentoscasaht)  
                                print(impedimentosvisitanteht)  
                                
                            elif nome_dado.strip() == faltas:

                                faltascasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                faltasvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(faltascasaht)  
                                print(faltasvisitanteht) 
                                
                            elif nome_dado.strip() == cartoesa:

                                cartoesacasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cartoesavisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cartoesacasaht)  
                                print(cartoesavisitanteht) 
                                
                            elif nome_dado.strip() == cartoesv:

                                cartoesvcasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cartoesvvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cartoesvcasaht)  
                                print(cartoesvvisitanteht) 
                                
                            elif nome_dado.strip() == grandeschances:

                                grandeschancescasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                grandeschancesvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(grandeschancescasaht)  
                                print(grandeschancesvisitanteht) 
                                
                            elif nome_dado.strip() == grandeschancesperdidas:

                                grandeschancesperdidascasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                grandeschancesperdidasvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(grandeschancesperdidascasaht)  
                                print(grandeschancesperdidasvisitanteht) 
                                
                            elif nome_dado.strip() == chutesnatrave:

                                chutesnatravecasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesnatravevisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesnatravecasaht)  
                                print(chutesnatravevisitanteht) 
                                
                            elif nome_dado.strip() == contraataques:

                                contraataquescasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                contraataquesvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(contraataquescasaht)  
                                print(contraataquesvisitanteht) 
                                
                            elif nome_dado.strip() == chutesdentroarea:

                                chutesdentroareacasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesdentroareavisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesdentroareacasaht)  
                                print(chutesdentroareavisitanteht) 
                                
                            elif nome_dado.strip() == chutesforaarea:

                                chutesforaareacasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesforaareavisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesforaareacasaht)  
                                print(chutesforaareavisitanteht) 
                                
                            elif nome_dado.strip() == defesasgoleiro:

                                defesasgoleirocasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                defesasgoleirovisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(defesasgoleirocasaht)  
                                print(defesasgoleirovisitanteht) 
                                
                            elif nome_dado.strip() == passes:

                                passescasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                passesvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(passescasaht)  
                                print(passesvisitanteht) 
                                
                            elif nome_dado.strip() == passescertos:

                                passescertoscasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip().split('(')[1].split('%')[0]
                                passescertosvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip().split('(')[1].split('%')[0]

                                print(nome_dado)
                                print(passescertoscasaht)  
                                print(passescertosvisitanteht) 
                                
                            elif nome_dado.strip() == bolaslongas:

                                bolaslongascasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                bolaslongasvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(bolaslongascasaht)  
                                print(bolaslongasvisitanteht) 
                                
                            elif nome_dado.strip() == cruza:

                                cruzacasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cruzavisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cruzacasaht)  
                                print(cruzavisitanteht) 
                                
                            elif nome_dado.strip() == dribles:

                                driblescasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                driblesvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(driblescasaht)  
                                print(driblesvisitanteht) 
                                
                            elif nome_dado.strip() == posseperdida:

                                posseperdidacasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                posseperdidavisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(posseperdidacasaht)  
                                print(posseperdidavisitanteht) 
                                
                            elif nome_dado.strip() == duelosganhos:

                                duelosganhoscasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                duelosganhosvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(duelosganhoscasaht)  
                                print(duelosganhosvisitanteht) 
                                
                            elif nome_dado.strip() == disputasaereasvencidas:

                                disputasaereasvencidascasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                disputasaereasvencidasvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(disputasaereasvencidascasaht)  
                                print(disputasaereasvencidasvisitanteht) 
                                
                            elif nome_dado.strip() == desarmes:

                                desarmescasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                desarmesvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(desarmescasaht)  
                                print(desarmesvisitanteht) 
                                
                            elif nome_dado.strip() == intercept:

                                interceptcasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                interceptvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(interceptcasaht)  
                                print(interceptvisitanteht) 
                                
                            elif nome_dado.strip() == distancias:

                                distanciascasaht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                distanciasvisitanteht = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()            

                                print(nome_dado)
                                print(distanciascasaht)  
                                print(distanciasvisitanteht)
                                
                                
                    # este else não vai ser executado pq o range dor for lá em cima não está em 3
                    # pq no momento esta informação não é necessária                               
                    else:                             
                        
                        # obtendo dados 2o tempo do jogo         
                        driver.find_element_by_css_selector('div.Tab__Wrapper-sc-1v9c4xe-0:nth-child(2) > div:nth-child(1) > div:nth-child(1) > a:nth-child(3)').click()
                        time.sleep(1)
                        
                        html = driver.execute_script("return document.documentElement.outerHTML")
                        page = bs(html, 'html.parser')
                        
                        trecho_codigo = page.find_all('',{'class':'Tabs__Content-vifb7j-1 jppjfQ'})[2]
                        tam_blocos = len(trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'}))                        
                    
                        # scaneando os dados
                        for tam_blocos1 in range(tam_blocos):
                        
                            nome_dado = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[1].find('div').text.strip()
                            
                            if nome_dado.strip() == possebola:

                                possebolacasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                possebolavisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(possebolacasa2t)  
                                print(possebolavisitante2t)  

                            elif nome_dado.strip() == chutes:

                                chutescasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutescasa2t)  
                                print(chutesvisitante2t)  
                                
                            elif nome_dado.strip() == chutesnogol:

                                chutesnogolcasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesnogolvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                
                                print(nome_dado)
                                print(chutesnogolcasa2t)  
                                print(chutesnogolvisitante2t)  
                            
                            elif nome_dado.strip() == chutesforagol:

                                chutesforagolcasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesforagolvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()
                                
                                print(nome_dado)
                                print(chutesforagolcasa2t)  
                                print(chutesforagolvisitante2t)  
                            
                            elif nome_dado.strip() == chutesbloqueados:

                                chutesbloqueadoscasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesbloqueadosvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesbloqueadoscasa2t)  
                                print(chutesbloqueadosvisitante2t)  
                                
                            elif nome_dado.strip() == corner: 

                                cornercasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cornervisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cornercasa2t)  
                                print(cornervisitante2t)  
                                
                            elif nome_dado.strip() == impedimentos:

                                impedimentoscasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                impedimentosvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(impedimentoscasa2t)  
                                print(impedimentosvisitante2t)  
                                
                            elif nome_dado.strip() == faltas:

                                faltascasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                faltasvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(faltascasa2t)  
                                print(faltasvisitante2t) 
                                
                            elif nome_dado.strip() == cartoesa:

                                cartoesacasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cartoesavisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cartoesacasa2t)  
                                print(cartoesavisitante2t) 
                                
                            elif nome_dado.strip() == cartoesv:

                                cartoesvcasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cartoesvvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cartoesvcasa2t)  
                                print(cartoesvvisitante2t) 
                                
                            elif nome_dado.strip() == grandeschances:

                                grandeschancescasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                grandeschancesvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(grandeschancescasa2t)  
                                print(grandeschancesvisitante2t) 
                                
                            elif nome_dado.strip() == grandeschancesperdidas:

                                grandeschancesperdidascasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                grandeschancesperdidasvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(grandeschancesperdidascasa2t)  
                                print(grandeschancesperdidasvisitante2t) 
                                
                            elif nome_dado.strip() == chutesnatrave:

                                chutesnatravecasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesnatravevisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesnatravecasa2t)  
                                print(chutesnatravevisitante2t) 
                                
                            elif nome_dado.strip() == contraataques:

                                contraataquescasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                contraataquesvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(contraataquescasa2t)  
                                print(contraataquesvisitante2t) 
                                
                            elif nome_dado.strip() == chutesdentroarea:

                                chutesdentroareacasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesdentroareavisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesdentroareacasa2t)  
                                print(chutesdentroareavisitante2t) 
                                
                            elif nome_dado.strip() == chutesforaarea:

                                chutesforaareacasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                chutesforaareavisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(chutesforaareacasa2t)  
                                print(chutesforaareavisitante2t) 
                                
                            elif nome_dado.strip() == defesasgoleiro:

                                defesasgoleirocasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                defesasgoleirovisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(defesasgoleirocasa2t)  
                                print(defesasgoleirovisitante2t) 
                                
                            elif nome_dado.strip() == passes:

                                passescasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                passesvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(passescasa2t)  
                                print(passesvisitante2t) 
                                
                            elif nome_dado.strip() == passescertos:

                                passescertoscasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip().split('(')[1].split('%')[0]
                                passescertosvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip().split('(')[1].split('%')[0]

                                print(nome_dado)
                                print(passescertoscasa2t)  
                                print(passescertosvisitante2t) 
                                
                            elif nome_dado.strip() == bolaslongas:

                                bolaslongascasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                bolaslongasvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(bolaslongascasa2t)  
                                print(bolaslongasvisitante2t) 
                                
                            elif nome_dado.strip() == cruza:

                                cruzacasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                cruzavisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(cruzacasa2t)  
                                print(cruzavisitante2t) 
                                
                            elif nome_dado.strip() == dribles:

                                driblescasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                driblesvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(driblescasa2t)  
                                print(driblesvisitante2t) 
                                
                            elif nome_dado.strip() == posseperdida:

                                posseperdidacasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                posseperdidavisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(posseperdidacasa2t)  
                                print(posseperdidavisitante2t) 
                                
                            elif nome_dado.strip() == duelosganhos:

                                duelosganhoscasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                duelosganhosvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(duelosganhoscasa2t)  
                                print(duelosganhosvisitante2t) 
                                
                            elif nome_dado.strip() == disputasaereasvencidas:

                                disputasaereasvencidascasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                disputasaereasvencidasvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(disputasaereasvencidascasa2t)  
                                print(disputasaereasvencidasvisitante2t) 
                                
                            elif nome_dado.strip() == desarmes:

                                desarmescasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                desarmesvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(desarmescasa2t)  
                                print(desarmesvisitante2t) 
                                
                            elif nome_dado.strip() == intercept:

                                interceptcasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                interceptvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()

                                print(nome_dado)
                                print(interceptcasa2t)  
                                print(interceptvisitante2t) 
                                
                            elif nome_dado.strip() == distancias:

                                distanciascasa2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[0].find('div').text.strip()
                                distanciasvisitante2t = trecho_codigo.find_all('',{'class':'Cell-decync-0 StatisticsStyles__StatisticsItemCell-zf4n59-2 dihIaT'})[tam_blocos1]\
                                        .find_all('',{'class':'Section-sc-1a7xrsb-0'})[2].find('div').text.strip()            

                                print(nome_dado)
                                print(distanciascasa2t)  
                                print(distanciastvisitante2t) 
                                
                                
                except:
                    continue
        

            # armazenando os dados coletados
            with open('dados_premier_league.csv', 'a', encoding='utf-8', newline='') as acsv:
                arq = csv.writer(acsv)
                arq.writerow([pais,campeonato,ano,time_casa,time_visitante\
                              ,golscasaht,golsvisitanteht,golscasaft,golsvisitanteft,resultadoht,resultadoft\
                              ,totalgolsht,totalgolsft,vencedorht,vencedorft,possebolacasaft,possebolavisitanteft\
                              ,possebolacasaht,possebolavisitanteht,chutescasaft,chutesvisitanteft,chutescasaht\
                              ,chutesvisitanteht,chutesnogolcasaft,chutesnogolvisitanteft,chutesnogolcasaht\
                              ,chutesnogolvisitanteht,chutesforagolcasaft,chutesforagolvisitanteft,chutesforagolcasaht\
                              ,chutesforagolvisitanteht,chutesbloqueadoscasaft,chutesbloqueadosvisitanteft,chutesbloqueadoscasaht\
                              ,chutesbloqueadosvisitanteht,cornercasaft,cornervisitanteft,cornercasaht,cornervisitanteht\
                              ,impedimentoscasaft,impedimentosvisitanteft,impedimentoscasaht,impedimentosvisitanteht,faltascasaft\
                              ,faltasvisitanteft,faltascasaht,faltasvisitanteht,cartoesacasaft,cartoesavisitanteft,cartoesacasaht\
                              ,cartoesavisitanteht,cartoesvcasaft,cartoesvvisitanteft,cartoesvcasaht,cartoesvvisitanteht\
                              ,grandeschancescasaft,grandeschancesvisitanteft,grandeschancescasaht,grandeschancesvisitanteht\
                              ,grandeschancesperdidascasaft,grandeschancesperdidasvisitanteft,grandeschancesperdidascasaht\
                              ,grandeschancesperdidasvisitanteht,chutesnatravecasaft,chutesnatravevisitanteft,chutesnatravecasaht\
                              ,chutesnatravevisitanteht,contraataquescasaft,contraataquesvisitanteft,contraataquescasaht\
                              ,contraataquesvisitanteht,chutesdentroareacasaft,chutesdentroareavisitanteft,chutesdentroareacasaht\
                              ,chutesdentroareavisitanteht,chutesforaareacasaft,chutesforaareavisitanteft,chutesforaareacasaht\
                              ,chutesforaareavisitanteht,defesasgoleirocasaft,defesasgoleirovisitanteft,defesasgoleirocasaht\
                              ,defesasgoleirovisitanteht,passescasaft,passesvisitanteft,passescasaht,passesvisitanteht\
                              ,passescertoscasaft,passescertosvisitanteft,passescertoscasaht,passescertosvisitanteht\
                              ,bolaslongascasaft,bolaslongasvisitanteft,bolaslongascasaht,bolaslongasvisitanteht,cruzacasaft\
                              ,cruzavisitanteft,cruzacasaht,cruzavisitanteht,driblescasaft,driblesvisitanteft,driblescasaht\
                              ,driblesvisitanteht,posseperdidacasaft,posseperdidavisitanteft,posseperdidacasaht\
                              ,posseperdidavisitanteht,duelosganhoscasaft,duelosganhosvisitanteft,duelosganhoscasaht\
                              ,duelosganhosvisitanteht,disputasaereasvencidascasaft,disputasaereasvencidasvisitanteft\
                              ,disputasaereasvencidascasaht,disputasaereasvencidasvisitanteht,desarmescasaft,desarmesvisitanteft\
                              ,desarmescasaht,desarmesvisitanteht,interceptcasaft,interceptvisitanteft,interceptcasaht\
                              ,interceptvisitanteht,distanciascasaft,distanciasvisitanteft,distanciascasaht,distanciasvisitanteht])
        
        

        except:
            
            print('exceção')
            
             # para fechar a aba do jogo que se está nela 
            driver.close()
            
            # mudar para a aba aberta antes - página principal 
            driver.switch_to.window(driver.window_handles[0])
            continue

            
            

# início do script principal



#url_inicio = 'https://www.sofascore.com'
url = 'https://www.sofascore.com/pt/torneio/futebol/england/premier-league/17'

 # comentar a linha abaixo se for usar o navegador invisível e descomentar linhas no topo
driver = webdriver.Firefox() 
driver.get(url)
time.sleep(5)

html = driver.execute_script("return document.documentElement.outerHTML")
page = bs(html, 'html.parser')

# 4 => ano 15/16. Aqui 1 unidade a menos é 1 ano a mais
# alterar o primeiro parâmetro do laço for abaixo quando precisar ajustar

# flag para interromper escaneamento
interromper_escaneamento = False
    
# percorrendo as temporadas a partir de 15/16
for i in range(1, 0, -1): 
    # interrompendo escaneamento
    if interromper_escaneamento == True:
        break
    
    # variável para auxiliar no ajuste
    rod_ant = 0
    verificador_rodadas = 0
    
    for j in range(2):
        # Informações de país e campeonato
        try:
            pais = driver.find_element_by_xpath('/html/body/div[1]/main/div/div[2]/div/div[1]/div[1]/div[2]/div/div/div[1]/div/div/span').text
            campeonato = driver.find_element_by_xpath('/html/body/div[1]/main/div/div[2]/div/div[1]/div[1]/div[2]/h2').text
            time.sleep(2)
            break
        except:
            time.sleep(2)
            continue
        
    # escolha do ano
    for escolhe in range(4):                    
        try:
            # clicando no menu para escolha do ano
            driver.find_element_by_css_selector('.styles__SeasonSelect-sc-1gqlp92-3 > div:nth-child(1) > button:nth-child(1)').click()
            time.sleep(3)
            
            # obtendo id de cada temporada
            temporadas = page.find_all('',{'class':'styles__Wrapper-sc-1c9nn5b-0 HoJZc select-scrollable ps ps--active-y'})[0].find_all('li')
            time.sleep(2)
            
            # escolhendo o ano desejado
            temporada = ''
            temporada = temporadas[i].get('id')
            time.sleep(1)

            # armazenando o ano - começando com 15/16
            ano = driver.find_element_by_css_selector('#' + temporada).text
            time.sleep(2)
        
            # escolhendo o ano - começando com 15/16 
            driver.find_element_by_css_selector('#' + temporada).click()
            time.sleep(2)   
 
            break
        except:
            print(f'exceção css_selector da temporada {temporada}')
            time.sleep(2)
            continue

    # classificando por rodadas   
    time.sleep(3)                                
    driver.find_element_by_css_selector('.u-mV12 > div:nth-child(2) > div:nth-child(1) > a:nth-child(2)').click()
    time.sleep(1)

    html = driver.execute_script("return document.documentElement.outerHTML")
    page = bs(html, 'html.parser')

    # varrendo as 38 rodadas
    for cont_rod in range(38):
        # testando se vai ser preciso fazer ajuste
        if (int(verificador_rodadas) - rod_ant != 1):
            
            # pedindo confirmação para continuar
            confirmacao = input('Deseja continuar? ')
            if confirmacao.lower() == 's' or confirmacao.lower() == 'sim':
                pass
            else:
                confirmacao2 = input('Tem certeza que vai parar? ')
                if confirmacao2.lower() == 's' or confirmacao2.lower() == 'sim':
                    interromper_escaneamento = True
                    break
                else:
                    pass  

        rod_ant = int(verificador_rodadas)
        
        # iniciando o scanner nas rodadas
        if cont_rod == 0: 
            
            for escolhe in range(4):
                try:

                    # clicando no menu para escolha da rodada
                    driver.find_element_by_css_selector('.ItemizedEventList__Select-sc-1g9vtzd-0 > div:nth-child(1) > button:nth-child(1)').click()
                    time.sleep(1)  
                    
                    # escolhendo a rodada 1                       
                    rodadas = page.find_all('',{'class':'styles__Wrapper-sc-1c9nn5b-0 HoJZc select-scrollable ps ps--active-y'})[1].find_all('li')
                    time.sleep(1)
                    
                    rodadas = rodadas[0].get('id')
                    driver.find_element_by_css_selector('#' + rodadas).click() 

                    # rolar a página mais para baixo
                    body = driver.find_element_by_css_selector('body')
                    body.send_keys(Keys.PAGE_DOWN)
                    time.sleep(1)

                    # verificando qual a rodada
                    var3 = str(cont_rod + 3)                                   
                    rod = driver.find_element_by_css_selector('.ItemizedEventList__Select-sc-1g9vtzd-0 > div:nth-child(1) > button:nth-child(1)').text
                    verificador_rodadas = rod.strip().split(' ')[1]  
                    print(rod)
                    break                    
                except:
                    continue
                    
            # chamando o scanner de rodadas e dados
            # descomentar o "if" e o "pass" abaixo e ajustar o valor de i referente à ano quando quiser ajustar
            if i == 1:
                pass
            
            # descomentar o "else" e identar a função "scanner" quando precisar ajustar
            else:
           
                scanner(pais, campeonato, ano, rod, cont_rod) 
                    

        else:
            for tente_outra_vez in range(4):
                try:
                    time.sleep(3)  

                    # clicando em próxima rodada  
                    driver.find_element_by_css_selector('.styles__EventListHeader-b3g57w-0 > div:nth-child(3) > div:nth-child(1)').click()
                    
                    time.sleep(4)                        
                    break                                
                except:
                    # clicando em próxima rodada
                    driver.find_element_by_css_selector('.styles__HeaderNavigationContent-b3g57w-1').click()
                    time.sleep(4)
                    break

            # verificando qual a rodada
            var3 = str(cont_rod + 3)
            
            for tente_outra_vez in range(4):
                try:
                    
                    rod = driver.find_element_by_css_selector('.ItemizedEventList__Select-sc-1g9vtzd-0 > div:nth-child(1) > button:nth-child(1)').text
                    verificador_rodadas = rod.strip().split(' ')[1] 
                    print(rod)

                    # cont_rod 0 => rodada 1
                    # descomentar a linha abaixo, alterar o "cont_rod", alterar o "i" e identar a chamada do "scanner()" quando precisar ajustar
                    if (cont_rod >= 34 or i <= 0) :
                    # chamando o scanner de rodadas e dados
                        scanner(pais, campeonato, ano, rod, cont_rod)
                    break
            
                except:
                    continue                    

driver.quit() # fecha o navegador
# Out:
# Deseja continuar? s
# Ronda 1
# Ronda 2
# Ronda 3
# Ronda 4
# Ronda 5
# Ronda 6
# Ronda 7
# Ronda 8
# Ronda 9
# Ronda 10
# Ronda 11
# Ronda 12
# Ronda 13
# Ronda 14
# Ronda 15
# Ronda 16
# Ronda 17
# Ronda 18
# Ronda 19
# Ronda 20
# Ronda 21
# Ronda 22
# Ronda 23
# Ronda 24
# Ronda 25
# Ronda 26
# Ronda 27
# Ronda 28
# Ronda 29
# Ronda 30
# Ronda 31
# Ronda 32
# Ronda 33
# Ronda 34
# Ronda 35
# Essa rodada tem 10 jogos
# rodada 35 jogo 1
# England
# Premier League
# 18/19
# Manchester City
# Tottenham
# golscasaht 1
# golsvisitanteht 0
# golscasaft 1
# golsvisitanteft 0
# resultado ht 1x0
# resultado ft 1x0
# total de gols ht 1
# total de gols ft 1
# vencedor ht H
# vencedor ft H
# Posse de bola
# 60%
# 40%
# Finalizações
# 15
# 10
# Finalizações no gol
# 4
# 4
# Finalizações para fora
# 6
# 3
# Chutes travados
# 5
# 3
# Escanteios
# 4
# 4
# Impedimentos
# 2
# 2
# Faltas
# 11
# 11
# Cartões amarelos
# 1
# 2
# Grandes oportunidades
# 2
# 2
# Grandes chances perdidas
# 1
# 2
# ...
