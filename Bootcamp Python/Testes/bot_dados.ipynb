# %%
# Aqui mesmo a página usando javascript conseguimos fazer web scraping 
# para isso usamos o selenium
# Aqui não abrimos o firefox

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

# descomentar estas 4 próximas linhas para usar o navegador invisível
#gecko = '/home/andre/Downloads/geckodriver'
#driver = webdriver.FirefoxOptions()
#driver.add_argument('-headless')
#driver = webdriver.Firefox(executable_path=gecko, options=driver)

def scanner(pais, campeonato, ano, rod, cont_rod):

    possebola = 'Posse de bola'
    chutes = 'Finalizações'
    chutesnogol = 'Finalizações no gol'
    chutesforagol = 'Finalizações para fora'
    chutesbloqueados = 'Chutes travados'
    corner = 'Escanteios'
    impedimentos = 'Impedimentos'
    faltas = 'Faltas'
    cartoesa = 'Cartões amarelos'
    cartoesv = 'Cartões vermelhos'
    grandeschances = 'Grandes chances'
    grandeschancesperdidas = 'Grandes chances perdidas'
    chutesnatrave = 'Finalizações na trave'
    contraataques = 'Contra-ataques'
    chutesdentroarea = 'Finalizações de dentro da área'
    chutesforaarea = 'Finalizações de fora da área'
    defesasgoleiro = 'Defesas do goleiro'
    passes = 'Passes'
    passescertos = 'Passes certos'
    bolaslongas = 'Bolas longas'
    cruza = 'Cruzamentos'
    dribles = 'Dribles'
    posseperdida = 'Possession lost'
    duelosganhos = 'Duelos ganhos'
    disputasaereasvencidas = 'Disputas aéreas vencidas'
    desarmes = 'Desarmes'
    intercept = 'Interceptações'
    cortes = 'Cortes'

    html = driver.execute_script("return document.documentElement.outerHTML")
    page = bs(html, 'html.parser')

    # contando o número de jogos da rodada 
    
    # auxiliar para pegar apenas o número da rodada e não a string "RODADA X"
    aux_rod = rod.split(' ')[1] 
    
    if aux_rod != '38':
        tam_classe_superior = len(page.find_all('',{'class':'js-event-list-tournament-events'}))
        tam = len(page.find_all('',{'class':'js-event-list-tournament-events'})[tam_classe_superior - 1].find_all('a'))
    else:
        tam = len(page.find_all('',{'class':'js-event-list-tournament-events'})[1].find_all('a'))
                
    rodada = rod  
    print(f'Essa rodada tem {tam} jogos')
    
    # Percorrendo todos os jogos da rodada
    for j in range(tam):
        try:

            # Inicialização de variáveis relacionadas à gols e minuto de gols
            gol1jogomin = '-1' 
            gol2jogomin = '-1'  
            gol3jogomin = '-1'
            gol4jogomin = '-1'
            gol5jogomin = '-1'
            gol6jogomin = '-1'
            gol7jogomin = '-1'
            gol8jogomin = '-1'
            gol9jogomin = '-1'
            gol10jogomin = '-1'
            gol11jogomin = '-1'
            gol12jogomin = '-1'
            gol13jogomin = '-1'

            gol1jogotime = 'null'
            gol2jogotime = 'null'
            gol3jogotime = 'null'
            gol4jogotime = 'null'
            gol5jogotime = 'null'
            gol6jogotime = 'null'
            gol7jogotime = 'null'
            gol8jogotime = 'null'
            gol9jogotime = 'null'
            gol10jogotime = 'null'
            gol11jogotime = 'null'
            gol12jogotime = 'null'
            gol13jogotime = 'null'

            gol1time1min = '-1'
            gol2time1min = '-1'
            gol3time1min = '-1'
            gol4time1min = '-1'
            gol5time1min = '-1'
            gol6time1min = '-1'
            gol7time1min = '-1'
            gol8time1min = '-1'
            gol9time1min = '-1'
            gol10time1min = '-1'

            gol1time2min = '-1'
            gol2time2min = '-1'
            gol3time2min = '-1'
            gol4time2min = '-1'
            gol5time2min = '-1'
            gol6time2min = '-1'
            gol7time2min = '-1'
            gol8time2min = '-1'
            gol9time2min = '-1'
            gol10time2min = '-1'

            mingol = []
            resultadopormin = []
            placar_ord = []
            min_ord = []
            resultadomin = []
            goltime = []
            golxtime1min = []
            golxtime2min = []
            
            # setando flag para sinalizar se a partida possui dados ht e ft 
            # caso seja necessário usar depois
            estatisticas_ht_ft = False

            # clicando nos jogos
            var1 = str(j + 1)
            var2 = str(cont_rod + 3)
            
            for tente_outra_vez in range(4):
                try:
                    time.sleep(3)              
                    if cont_rod == 37:

                        # clicando nos jogos da rodada 37
                        driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[3]/div[3]/div/div[1]/div[3]/div[2]/div/div/div[2]/div[2]/div[2]/a['+ var1 +']').click()
                    else:

                        # clicando nos jogos
                        driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[3]/div[3]/div/div[1]/div[3]/div[2]/div/div/div['+ var2 +']/div[2]/div[2]/a['+ var1 +']').click()
                    
                    time.sleep(4)
                 
                    # pegando o nome dos times
                    time1 = driver.find_element_by_css_selector('.h-interactive > span:nth-child(1)').text
                    time2 = driver.find_element_by_css_selector('.h-interactive > span:nth-child(2)').text
                  
                    # Abrindo página com os dados da partida
                    driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[3]/div[3]/div/div[2]/div/div/div[1]/div[1]/a').click()
                    time.sleep(8)                 
                  
                    # mudar para a nova aba aberta
                    driver.switch_to.window(driver.window_handles[1])
                  
                    break
                    
                except:
                    continue                
                
            # verificando se o jogo tem os dados ht e ft          
            driver.find_element_by_css_selector('ul.nav:nth-child(2) > li:nth-child(1) > a:nth-child(1)').click()               
                                                 
            # se chegou aqui o jogo possui estatísticas ht e ft, então seta uma flag
            # caso seja necessário usar depois
            estatisticas_ht_ft = True

            # Coletando informações do jogo                      
            data = driver.find_element_by_css_selector('.cell--start > div:nth-child(1) > div:nth-child(1)').text  
            resultadoft = driver.find_element_by_css_selector('.details__score-cell > div:nth-child(2) > div:nth-child(1)').text.strip()
            resultadoft = resultadoft[0] + 'x' + resultadoft[4]                
            golscasaft = resultadoft[0]                       
            golsvisitanteft = resultadoft[2]

            resultadoht = driver.find_element_by_css_selector('.details__score-cell > div:nth-child(2) > div:nth-child(2)').text.strip()
            resultadoht = resultadoht[1] + 'x' + resultadoht[5]
            golscasaht = resultadoht[0]
            golsvisitanteht = resultadoht[2]

            golscasa2t = int(golscasaft) - int(golscasaht)
            golsvisitante2t = int(golsvisitanteft) - int(golsvisitanteht)

            totalgolsft = int(golscasaft) + int(golsvisitanteft)
            totalgolsht = int(golscasaht) + int(golsvisitanteht)

            print(pais)                             
            print(campeonato)
            print(ano)
            print(data)
            print(time1)
            print(time2)
            
            print(f'golscasaht {golscasaht}')
            print(f'golsvisitanteht {golsvisitanteht}')
            print(f'golscasaft {golscasaft}')
            print(f'golsvisitanteft {golsvisitanteft}')
            print(f'resultado ht {resultadoht}')
            print(f'resultado ft {resultadoft}')
            print(f'total de gols ht {totalgolsht}')
            print(f'total de gols ft {totalgolsft}')

            # rolar a página mais para baixo
            body = driver.find_element_by_css_selector('body')
            body.send_keys(Keys.PAGE_DOWN)
            time.sleep(1) 

            html = driver.execute_script("return document.documentElement.outerHTML")
            page = bs(html, 'html.parser')


            # aqui começa a coleta de minuto de 1o gol 2o gol, placar em 5 e 5 min, quem fez o 1o
            # o 2o gol do jogo              

            # contando quantos gols aconteceram no jogo
            tam_placar = len(page.find_all('',{'class':'incident__goal'}))

            # contando quantos gols cada time fez
            tam_minutogol = len(page.find('div',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '}))
            tam_minutogol2 = len(page.find('div',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '}))

            # coletando o minuto dos gols

            # minuto que o placar mudou e novo placar
            for totalgols in range(tam_placar):
                placarpormin = page.find_all('',{'class':'incident__goal'})[totalgols].text.strip().replace(' - ','x')
                resultadopormin.append(placarpormin)

            # gols do time 1
            for minutosgols in range(tam_minutogol):
                try:
                    teste = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[minutosgols].find('span',{'class':'incident__goal'}).text.strip().replace(' - ','x')
                    minutogol = int(page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[minutosgols].find('',{'cell__content incident__time'}).text.strip().split("'")[0])
                    mingol.append(minutogol)
                    
                    # verificando os gols depois dos 90 min
                    if mingol[len(mingol) - 1] == 90:
                        try:                                                                                                                                                                                                      
                            mingolacrescimo = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[minutosgols].find('',{'cell__content incident__time'}).find('sup').text.strip().split("+")[1] 
                            mingolacrescimo = int(mingolacrescimo) + int(mingol[len(mingol) - 1])
                            mingol[len(mingol) - 1] = mingolacrescimo
                        except:
                            pass

                    
                    # goltime armazena o placar e quem fez o gol
                    goltime.append(teste)
                    goltime.append('1')

                    # verifica o minuto do 1o, 2o, 3o gol do time 1
                    golxtime1min.append(mingol[len(mingol) - 1])

                except:
                    continue

            # gols do time 2       
            for minutosgols2 in range(tam_minutogol2):
                try:
                    teste2 = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[minutosgols2].find('span',{'class':'incident__goal'}).text.strip().replace(' - ','x')
                    minutogol = int(page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[minutosgols2].find('',{'cell__content incident__time'}).text.strip().split("'")[0])
                    mingol.append(minutogol)
                    
                    # verificando os gols depois dos 90 min
                    if mingol[len(mingol) - 1] == 90:
                        try:                                                                                                                                                                                                      
                            mingolacrescimo = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[minutosgols2].find('',{'cell__content incident__time'}).find('sup').text.strip().split("+")[1] 
                            mingolacrescimo = int(mingolacrescimo) + int(mingol[len(mingol) - 1])
                            mingol[len(mingol) - 1] = mingolacrescimo
                        except:
                            pass
        
                        
                    # goltime armazena o placar e quem fez o gol
                    goltime.append(teste2)
                    goltime.append('2')

                    # verifica o minuto do 1o, 2o, 3o gol do time 2
                    golxtime2min.append(mingol[len(mingol) - 1])

                except:
                    continue   

            # vamos precisar saber o tamanho desse array
            tam_goltime = len(goltime)

            # variáveis auxiliares que receberam o placar por min de gol e o min dos gols sendo ordenadas
            resultadopormin.reverse()
            golxtime1min.reverse()
            golxtime2min.reverse()
            mingol.sort()
            
            for ordena in range(len(mingol)):
                resultadomin.append(mingol[ordena])
                resultadomin.append(resultadopormin[ordena])

            # vai salvar no máximo 13 gols em uma partida por ser desnecessário
            # mais que isso
            if int(totalgolsft) > 13:
                quant_gols = 13
            else:
                quant_gols = int(totalgolsft)

            # verificando o min dos gols e quem marcou
            for ver_minuto in range(quant_gols):
                print(f'gol{ver_minuto + 1}jogomin = {mingol[ver_minuto]}') 

                # verificando de quem foi o gol
                for cont1 in range(tam_goltime):
                    if resultadopormin[ver_minuto] == goltime[cont1]:
                        print(f'gol{ver_minuto + 1}jogotime = {goltime[cont1 + 1]}')

            # verificando o min do 1o gol e do 2o de cada time
            tam_golxtime1min = len(golxtime1min)
            tam_golxtime2min = len(golxtime2min)

            for y in range(tam_golxtime1min):
                print(f'gol{y+1}time1min = {golxtime1min[y]}')

            for z in range(tam_golxtime2min):
                print(f'gol{z+1}time2min = {golxtime2min[z]}')
                
            print(f'resultado por min {resultadopormin}')
            print(f'placar e min do placar {resultadomin}') 


            # testando se o jogo foi 0x0
            if resultadoft == '0x0':
                mingol.append('-1')
                resultadopormin.append('0x0')
                goltime.append('null')
                resultadomin.append('0x0')
                resultadomin.append('-1')

                print(f'gol{1}jogomin = {mingol[0]}')
                print(f'gol{1}jogotime = {goltime[0]}')
                print(f'resultado por min {resultadopormin[0]}')
                print(f'placar e min do placar {resultadomin}')


            # verificando se algum dos times não teve seu 1o ou 2o gol na partida
            if golscasaft == '0':
                golxtime1min.append('-1')
                print(f'gol{1}time1min = {golxtime1min[0]}')

            if golsvisitanteft == '0':
                golxtime2min.append('-1')
                print(f'gol{1}time2min = {golxtime2min[0]}')
                

            # Pegando as estatísticas de cada jogo no ft, ht e 2o tempo
             
            for intervalos in range(3):
                try:
                    if intervalos == 0:

                        # quantidade de dados ft
                        tam_blocos = len(page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})) 
      
                        # scaneando os dados
                        for tam_blocos1 in range(tam_blocos):
                          
                            nome_dado = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find('',{'class':'cell__section--main u-tC'}).text.strip()

                            if nome_dado.strip() == possebola:

                                possebolacasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                possebolavisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(possebolacasaft)  
                                print(possebolavisitanteft)  

                            elif nome_dado.strip() == chutes:

                                chutescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutescasaft)  
                                print(chutesvisitanteft)  
                                
                            elif nome_dado.strip() == chutesnogol:

                                chutesnogolcasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesnogolvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()
                                
                                print(nome_dado)
                                print(chutesnogolcasaft)  
                                print(chutesnogolvisitanteft)  
                            
                            elif nome_dado.strip() == chutesforagol:

                                chutesforagolcasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesforagolvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()
                                
                                print(nome_dado)
                                print(chutesforagolcasaft)  
                                print(chutesforagolvisitanteft)  
                            
                            elif nome_dado.strip() == chutesbloqueados:

                                chutesbloqueadoscasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesbloqueadosvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesbloqueadoscasaft)  
                                print(chutesbloqueadosvisitanteft)  
                                
                            elif nome_dado.strip() == corner: 

                                cornercasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cornervisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cornercasaft)  
                                print(cornervisitanteft)  
                                
                            elif nome_dado.strip() == impedimentos:

                                impedimentoscasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                impedimentosvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(impedimentoscasaft)  
                                print(impedimentosvisitanteft)  
                                
                            elif nome_dado.strip() == faltas:

                                faltascasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                faltasvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(faltascasaft)  
                                print(faltasvisitanteft) 
                                
                            elif nome_dado.strip() == cartoesa:

                                cartoesacasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cartoesavisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cartoesacasaft)  
                                print(cartoesavisitanteft) 
                                
                            elif nome_dado.strip() == cartoesv:

                                cartoesvcasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cartoesvvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cartoesvcasaft)  
                                print(cartoesvvisitanteft) 
                                
                            elif nome_dado.strip() == grandeschances:

                                grandeschancescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                grandeschancesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(grandeschancescasaft)  
                                print(grandeschancesvisitanteft) 
                                
                            elif nome_dado.strip() == grandeschancesperdidas:

                                grandeschancesperdidascasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                grandeschancesperdidasvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(grandeschancesperdidascasaft)  
                                print(grandeschancesperdidasvisitanteft) 
                                
                            elif nome_dado.strip() == chutesnatrave:

                                chutesnatravecasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesnatravevisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesnatravecasaft)  
                                print(chutesnatravevisitanteft) 
                                
                            elif nome_dado.strip() == contraataques:

                                contraataquescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                contraataquesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(contraataquescasaft)  
                                print(contraataquesvisitanteft) 
                                
                            elif nome_dado.strip() == chutesdentroarea:

                                chutesdentroareacasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesdentroareavisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesdentroareacasaft)  
                                print(chutesdentroareavisitanteft) 
                                
                            elif nome_dado.strip() == chutesforaarea:

                                chutesforaareacasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesforaareavisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesforaareacasaft)  
                                print(chutesforaareavisitanteft) 
                                
                            elif nome_dado.strip() == defesasgoleiro:

                                defesasgoleirocasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                defesasgoleirovisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(defesasgoleirocasaft)  
                                print(defesasgoleirovisitanteft) 
                                
                            elif nome_dado.strip() == passes:

                                passescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                passesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(passescasaft)  
                                print(passesvisitanteft) 
                                
                            elif nome_dado.strip() == passescertos:

                                passescertoscasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                passescertosvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(passescertoscasaft)  
                                print(passescertosvisitanteft) 
                                
                            elif nome_dado.strip() == bolaslongas:

                                bolaslongascasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                bolaslongasvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(bolaslongascasaft)  
                                print(bolaslongasvisitanteft) 
                                
                            elif nome_dado.strip() == cruza:

                                cruzacasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cruzavisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cruzacasaft)  
                                print(cruzavisitanteft) 
                                
                            elif nome_dado.strip() == dribles:

                                driblescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                driblesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(driblescasaft)  
                                print(driblesvisitanteft) 
                                
                            elif nome_dado.strip() == posseperdida:

                                posseperdidacasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                posseperdidavisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(posseperdidacasaft)  
                                print(posseperdidavisitanteft) 
                                
                            elif nome_dado.strip() == duelosganhos:

                                duelosganhoscasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                duelosganhosvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(duelosganhoscasaft)  
                                print(duelosganhosvisitanteft) 
                                
                            elif nome_dado.strip() == disputasaereasvencidas:

                                disputasaereasvencidascasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                disputasaereasvencidasvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(disputasaereasvencidascasaft)  
                                print(disputasaereasvencidasvisitanteft) 
                                
                            elif nome_dado.strip() == desarmes:

                                desarmescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                desarmesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(desarmescasaft)  
                                print(desarmesvisitanteft) 
                                
                            elif nome_dado.strip() == intercept:

                                interceptcasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                interceptvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(interceptcasaft)  
                                print(interceptvisitanteft) 
                                
                            elif nome_dado.strip() == cortes:

                                cortescasaft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cortesvisitanteft = page.find(id = 'statistics-period-ALL').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()            

                                print(nome_dado)
                                print(cortescasaft)  
                                print(cortestvisitanteft) 
                    
                    elif intervalos == 1:
                        
                        # obtendo dados 1o tempo do jogo            
                        driver.find_element_by_css_selector('ul.nav:nth-child(2) > li:nth-child(2) > a:nth-child(1)').click()
                        
                        # quantidade de dados ht
                        tam_blocos = len(page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})) 

                        # scaneando os dados
                        for tam_blocos1 in range(tam_blocos):
                           
                            nome_dado = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find('',{'class':'cell__section--main u-tC'}).text.strip()

                            if nome_dado.strip() == possebola:

                                possebolacasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                possebolavisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(possebolacasaht)  
                                print(possebolavisitanteht)  

                            elif nome_dado.strip() == chutes:

                                chutescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutescasaht)  
                                print(chutesvisitanteht)  
                                
                            elif nome_dado.strip() == chutesnogol:

                                chutesnogolcasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesnogolvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()
                                
                                print(nome_dado)
                                print(chutesnogolcasaht)  
                                print(chutesnogolvisitanteht)  
                            
                            elif nome_dado.strip() == chutesforagol:

                                chutesforagolcasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesforagolvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()
                                
                                print(nome_dado)
                                print(chutesforagolcasaht)  
                                print(chutesforagolvisitanteht)  
                            
                            elif nome_dado.strip() == chutesbloqueados:

                                chutesbloqueadoscasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesbloqueadosvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesbloqueadoscasaht)  
                                print(chutesbloqueadosvisitanteht)  
                                
                            elif nome_dado.strip() == corner: 

                                cornercasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cornervisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cornercasaht)  
                                print(cornervisitanteht)  
                                
                            elif nome_dado.strip() == impedimentos:

                                impedimentoscasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                impedimentosvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(impedimentoscasaht)  
                                print(impedimentosvisitanteht)  
                                
                            elif nome_dado.strip() == faltas:

                                faltascasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                faltasvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(faltascasaht)  
                                print(faltasvisitanteht) 
                                
                            elif nome_dado.strip() == cartoesa:

                                cartoesacasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cartoesavisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cartoesacasaht)  
                                print(cartoesavisitanteht) 
                                
                            elif nome_dado.strip() == cartoesv:

                                cartoesvcasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cartoesvvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cartoesvcasaht)  
                                print(cartoesvvisitanteht) 
                                
                            elif nome_dado.strip() == grandeschances:

                                grandeschancescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                grandeschancesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(grandeschancescasaht)  
                                print(grandeschancesvisitanteht) 
                                
                            elif nome_dado.strip() == grandeschancesperdidas:

                                grandeschancesperdidascasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                grandeschancesperdidasvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(grandeschancesperdidascasaht)  
                                print(grandeschancesperdidasvisitanteht) 
                                
                            elif nome_dado.strip() == chutesnatrave:

                                chutesnatravecasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesnatravevisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesnatravecasaht)  
                                print(chutesnatravevisitanteht) 
                                
                            elif nome_dado.strip() == contraataques:

                                contraataquescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                contraataquesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(contraataquescasaht)  
                                print(contraataquesvisitanteht) 
                                
                            elif nome_dado.strip() == chutesdentroarea:

                                chutesdentroareacasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesdentroareavisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesdentroareacasaht)  
                                print(chutesdentroareavisitanteht) 
                                
                            elif nome_dado.strip() == chutesforaarea:

                                chutesforaareacasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesforaareavisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesforaareacasaht)  
                                print(chutesforaareavisitanteht) 
                                
                            elif nome_dado.strip() == defesasgoleiro:

                                defesasgoleirocasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                defesasgoleirovisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(defesasgoleirocasaht)  
                                print(defesasgoleirovisitanteht) 
                                
                            elif nome_dado.strip() == passes:

                                passescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                passesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(passescasaht)  
                                print(passesvisitanteht) 
                                
                            elif nome_dado.strip() == passescertos:

                                passescertoscasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                passescertosvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(passescertoscasaht)  
                                print(passescertosvisitanteht) 
                                
                            elif nome_dado.strip() == bolaslongas:

                                bolaslongascasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                bolaslongasvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(bolaslongascasaht)  
                                print(bolaslongasvisitanteht) 
                                
                            elif nome_dado.strip() == cruza:

                                cruzacasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cruzavisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cruzacasaht)  
                                print(cruzavisitanteht) 
                                
                            elif nome_dado.strip() == dribles:

                                driblescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                driblesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(driblescasaht)  
                                print(driblesvisitanteht) 
                                
                            elif nome_dado.strip() == posseperdida:

                                posseperdidacasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                posseperdidavisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(posseperdidacasaht)  
                                print(posseperdidavisitanteht) 
                                
                            elif nome_dado.strip() == duelosganhos:

                                duelosganhoscasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                duelosganhosvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(duelosganhoscasaht)  
                                print(duelosganhosvisitanteht) 
                                
                            elif nome_dado.strip() == disputasaereasvencidas:

                                disputasaereasvencidascasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                disputasaereasvencidasvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(disputasaereasvencidascasaht)  
                                print(disputasaereasvencidasvisitanteht) 
                                
                            elif nome_dado.strip() == desarmes:

                                desarmescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                desarmesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(desarmescasaht)  
                                print(desarmesvisitanteht) 
                                
                            elif nome_dado.strip() == intercept:

                                interceptcasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                interceptvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(interceptcasaht)  
                                print(interceptvisitanteht) 
                                
                            elif nome_dado.strip() == cortes:

                                cortescasaht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cortesvisitanteht = page.find(id = 'statistics-period-1ST').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()            

                                print(nome_dado)
                                print(cortescasaht)  
                                print(cortestvisitanteht)
                               
                    else:
                        
                        # obtendo dados 2o tempo do jogo            
                        driver.find_element_by_css_selector('ul.nav:nth-child(2) > li:nth-child(3) > a:nth-child(1)').click()
                        print('oi 1')
                        # quantidade de dados 2t
                        tam_blocos = len(page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})) 
                       
                        # scaneando os dados
                        for tam_blocos1 in range(tam_blocos):
                        
                            nome_dado = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find('',{'class':'cell__section--main u-tC'}).text.strip()

                            if nome_dado.strip() == possebola:

                                possebolacasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                possebolavisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(possebolacasa2t)  
                                print(possebolavisitante2t)  

                            elif nome_dado.strip() == chutes:

                                chutescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutescasa2t)  
                                print(chutesvisitante2t)  
                                
                            elif nome_dado.strip() == chutesnogol:

                                chutesnogolcasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesnogolvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()
                                
                                print(nome_dado)
                                print(chutesnogolcasa2t)  
                                print(chutesnogolvisitante2t)  
                            
                            elif nome_dado.strip() == chutesforagol:

                                chutesforagolcasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesforagolvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()
                                
                                print(nome_dado)
                                print(chutesforagolcasa2t)  
                                print(chutesforagolvisitante2t)  
                            
                            elif nome_dado.strip() == chutesbloqueados:

                                chutesbloqueadoscasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesbloqueadosvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesbloqueadoscasa2t)  
                                print(chutesbloqueadosvisitante2t)  
                                
                            elif nome_dado.strip() == corner: 

                                cornercasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cornervisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cornercasa2t)  
                                print(cornervisitante2t)  
                                
                            elif nome_dado.strip() == impedimentos:

                                impedimentoscasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                impedimentosvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(impedimentoscasa2t)  
                                print(impedimentosvisitante2t)  
                                
                            elif nome_dado.strip() == faltas:

                                faltascasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                faltasvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(faltascasa2t)  
                                print(faltasvisitante2t) 
                                
                            elif nome_dado.strip() == cartoesa:

                                cartoesacasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cartoesavisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cartoesacasa2t)  
                                print(cartoesavisitante2t) 
                                
                            elif nome_dado.strip() == cartoesv:

                                cartoesvcasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cartoesvvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cartoesvcasa2t)  
                                print(cartoesvvisitante2t) 
                                
                            elif nome_dado.strip() == grandeschances:

                                grandeschancescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                grandeschancesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(grandeschancescasa2t)  
                                print(grandeschancesvisitante2t) 
                                
                            elif nome_dado.strip() == grandeschancesperdidas:

                                grandeschancesperdidascasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                grandeschancesperdidasvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(grandeschancesperdidascasa2t)  
                                print(grandeschancesperdidasvisitante2t) 
                                
                            elif nome_dado.strip() == chutesnatrave:

                                chutesnatravecasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesnatravevisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesnatravecasa2t)  
                                print(chutesnatravevisitante2t) 
                                
                            elif nome_dado.strip() == contraataques:

                                contraataquescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                contraataquesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(contraataquescasa2t)  
                                print(contraataquesvisitante2t) 
                                
                            elif nome_dado.strip() == chutesdentroarea:

                                chutesdentroareacasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesdentroareavisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesdentroareacasa2t)  
                                print(chutesdentroareavisitante2t) 
                                
                            elif nome_dado.strip() == chutesforaarea:

                                chutesforaareacasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                chutesforaareavisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(chutesforaareacasa2t)  
                                print(chutesforaareavisitante2t) 
                                
                            elif nome_dado.strip() == defesasgoleiro:

                                defesasgoleirocasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                defesasgoleirovisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(defesasgoleirocasa2t)  
                                print(defesasgoleirovisitante2t) 
                                
                            elif nome_dado.strip() == passes:

                                passescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                passesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(passescasa2t)  
                                print(passesvisitante2t) 
                                
                            elif nome_dado.strip() == passescertos:

                                passescertoscasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                passescertosvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(passescertoscasa2t)  
                                print(passescertosvisitante2t) 
                                
                            elif nome_dado.strip() == bolaslongas:

                                bolaslongascasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                bolaslongasvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(bolaslongascasa2t)  
                                print(bolaslongasvisitante2t) 
                                
                            elif nome_dado.strip() == cruza:

                                cruzacasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cruzavisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(cruzacasa2t)  
                                print(cruzavisitante2t) 
                                
                            elif nome_dado.strip() == dribles:

                                driblescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                driblesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(driblescasa2t)  
                                print(driblesvisitante2t) 
                                
                            elif nome_dado.strip() == posseperdida:

                                posseperdidacasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                posseperdidavisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(posseperdidacasa2t)  
                                print(posseperdidavisitante2t) 
                                
                            elif nome_dado.strip() == duelosganhos:

                                duelosganhoscasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                duelosganhosvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(duelosganhoscasa2t)  
                                print(duelosganhosvisitante2t) 
                                
                            elif nome_dado.strip() == disputasaereasvencidas:

                                disputasaereasvencidascasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                disputasaereasvencidasvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(disputasaereasvencidascasa2t)  
                                print(disputasaereasvencidasvisitante2t) 
                                
                            elif nome_dado.strip() == desarmes:

                                desarmescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                desarmesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(desarmescasa2t)  
                                print(desarmesvisitante2t) 
                                
                            elif nome_dado.strip() == intercept:

                                interceptcasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                interceptvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()

                                print(nome_dado)
                                print(interceptcasa2t)  
                                print(interceptvisitante2t) 
                                
                            elif nome_dado.strip() == cortes:

                                cortescasa2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[0].text.strip()
                                cortesvisitante2t = page.find(id = 'statistics-period-2ND').find_all('',{'class':'cell cell--incident'})[tam_blocos1].find_all('',{'class':'cell__section'})[1].text.strip()            

                                print(nome_dado)
                                print(cortescasa2t)  
                                print(cortestvisitante2t) 
                                
                                
                except:
                    continue
            

            # para fechar a aba do jogo que se está nela 
            driver.close()
 
            # mudar para a aba aberta antes - página principal 
            driver.switch_to.window(driver.window_handles[0])
            print(f'Jogo {j + 1} {rodada} ano {ano}')
            
        except:
            
            print('exceção')
            
             # para fechar a aba do jogo que se está nela 
            driver.close()
            
            # mudar para a aba aberta antes - página principal 
            driver.switch_to.window(driver.window_handles[0])
            continue

            
            

# início do script principal



#url_inicio = 'https://www.sofascore.com'
url = 'https://www.sofascore.com/pt/torneio/futebol/brazil/brasileiro-serie-a/325'

 # comentar a linha abaixo se for usar o navegador invisível e descomentar linhas no topo
driver = webdriver.Firefox() 
driver.get(url)
time.sleep(1)

# 4 => ano 2016. Aqui 1 unidade a menos é 1 ano a mais
# alterar o primeiro parâmetro do laço for abaixo quando precisar ajustar
for i in range(3, 0, -1): 
    # variável para auxiliar no ajuste
    rod_ant = 0
    verificador_rodadas = 0
    var_temporada = str(i)
    temporada = '.dropdown__menu--scroll > li:nth-child('+ var_temporada +') > a:nth-child(1)'

    for j in range(2):
        # Informações de país e campeonato
        try:
            pais = driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[1]/a/span').text
            campeonato = driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[2]/h2').text
            time.sleep(2)
            break
        except:
            time.sleep(4)
            continue
        
    # escolha do ano
    for escolhe in range(4):
        try:
            # clicando no menu para escolha do ano
            driver.find_element_by_css_selector('.u-pos-absolute > div:nth-child(1) > div:nth-child(1) > button:nth-child(1) > span:nth-child(1)').click()
            time.sleep(2)

            # Para mudar de temporada começar mudando o armazenamento do ano abaixo
            # e depois mudar o ano de fato

            # armazenando o ano - começando com 2016
            ano = driver.find_element_by_css_selector(temporada).text
            time.sleep(1)

            # escolhendo o ano - começando com 2016
            driver.find_element_by_css_selector(temporada).click()
            time.sleep(2)   
 
            break
        except:
            continue

    # classificando por rodadas   
    time.sleep(3)
    driver.find_element_by_css_selector('.js-tournament-page-events-select-round').click()
    time.sleep(1)

    html = driver.execute_script("return document.documentElement.outerHTML")
    page = bs(html, 'html.parser')

    # varrendo as 38 rodadas
    for cont_rod in range(38):
        # testando se vai ser preciso fazer ajuste
        if (int(verificador_rodadas) - rod_ant != 1):
            
            # pedindo confirmação para continuar
            confirmacao = input('Deseja continuar? ')
            if confirmacao.lower() == 's':
                pass
            else:
                confirmacao2 = input('Tem certeza que vai parar? ')
                if confirmacao2.lower() == 's':
                    driver.quit()
                else:
                    pass  

        rod_ant = int(verificador_rodadas)
        
        # iniciando o scanner nas rodadas
        if cont_rod == 0: 
            
            for escolhe in range(4):
                try:

                    # clicando no menu para escolha da rodada
                    driver.find_element_by_css_selector('.js-select-events-by-round-container > div:nth-child(2) > div:nth-child(1) > div:nth-child(1) > button:nth-child(1) > span:nth-child(1)').click()
                    time.sleep(1)

                    # escolhendo a rodada 1              .            
                    driver.find_element_by_css_selector('.js-select-round-dropdown > li:nth-child(1) > a:nth-child(1)').click()
                    time.sleep(1)

                    # rolar a página mais para baixo
                    body = driver.find_element_by_css_selector('body')
                    body.send_keys(Keys.PAGE_DOWN)
                    time.sleep(1)

                    # verificando qual a rodada
                    var3 = str(cont_rod + 3)  
                    rod = driver.find_element_by_css_selector('div.event-list-table-wrapper:nth-child('+ var3 +') > div:nth-child(1) > div:nth-child(1) > div:nth-child(1)').text
                    verificador_rodadas = rod.split(' ')[1]  
                    
                    break
                    
                except:
                    continue
                    
            # chamando o scanner de rodadas e dados
            # descomentar o "if" e o "pass" abaixo e ajustar o valor de i referente à ano quando quiser ajustar
            if i == 5:
                pass
            # descomentar o "else" e identar a função "scanner" quando precisar ajustar
            else:
                scanner(pais, campeonato, ano, rod, cont_rod) 
                    

        else:
            for tente_outra_vez in range(4):
                try:
                    time.sleep(3)  

                    # clicando em próxima rodada                
                    driver.find_element_by_css_selector('.js-tournament-page-show-next-round > span:nth-child(1)').click()
                    time.sleep(4)
                    break
                except:
                    continue

            # verificando qual a rodada
            var3 = str(cont_rod + 3)
            
            for tente_outra_vez in range(4):
                try:

                    # tratamento para última rodada em que muda o css_selector da string "RODADA X"
                    if cont_rod == 37:
                        rod = driver.find_element_by_css_selector('.js-uniqueTournament-page-events-round-container > div:nth-child(2) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1)').text
                        verificador_rodadas = rod.split(' ')[1] 
                    else:
                        rod = driver.find_element_by_css_selector('div.event-list-table-wrapper:nth-child('+ var3 +') > div:nth-child(1) > div:nth-child(1) > div:nth-child(1)').text
                        verificador_rodadas = rod.split(' ')[1] 

                    # cont_rod 0 => rodada 1
                    # descomentar a linha abaixo, alterar o "cont_rod", alterar o "i" e identar a chamada do "scanner()" quando precisar ajustar
                    if (cont_rod >= 2 or i < 3) :
                    # chamando o scanner de rodadas e dados
                        scanner(pais, campeonato, ano, rod, cont_rod)
                    break
            
                except:
                    continue

driver.quit() # fecha o navegador
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-c9f4ea6e05b3> in <module>
#    1231     # classificando por rodadas
#    1232     time.sleep(3)
# -> 1233     driver.find_element_by_css_selector('.js-tournament-page-events-select-round').click()
#    1234     time.sleep(1)
#    1235
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
import threading
import time
 

def worker():
    inp = ''
    while inp.lower() != 'f':
        inp = input('digite ')
 

t = threading.Thread(target=worker)
t.start()
while t.isAlive():
    print("Aguardando thread")
    time.sleep(1)
    inp = 'f'
 
print("Programa finalizado")
# Out:
# Aguardando thread
# Aguardando thread
# Aguardando thread
# Aguardando thread
# Aguardando thread
# digite f
# Programa finalizado

# %%
# verificando semelhança de strings através do ratio ( mais rígido )
# bom na mineração de dados

from fuzzywuzzy import fuzz

arg1 = 'Agorc x Megt & Centre'.lower()
arg2 = 'AGORC Bangalore x MEG'.lower()
fuzz.ratio(arg1, arg2)
# Out:
# 52

# %%
# verificando semelhança de strings através do partial_ratio ( menos rígido )
# bom na mineração de dados

from fuzzywuzzy import fuzz

arg1 = 'Agorc x Megt & Centre'.lower()
arg2 = 'AGORC Bangalore x MEG'.lower()
fuzz.partial_ratio(arg1, arg2)
# Out:
# 52
